# %% [markdown]
# # Regression Predict Student Solution
#
# © Explore Data Science Academy
#
# ---
# ### Honour Code
#
# The members of {**2207_NM4**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
#  ### COLLABORATORS
# - ⚡ Emmanuel Obeng Afari - **Ghana**
# - ⚡ Chukwuemeka Okezue - **Nigeria**
# - ⚡ Ngawetu Mtirara - **South Africa**
# - ⚡ Malik Kabir - **Nigeria**
# - ⚡ Mbuyiselo Mkwanazi - **South Africa**
#
# Non-compliance with the honour code constitutes a material breach of contract.
#
# ### Predict Overview: Spain Electricity Shortfall Challenge
#
# The government of Spain is considering an expansion of it's renewable energy resource infrastructure investments. As such, they require information on the trends and patterns of the countries renewable sources and fossil fuel energy generation. Your company has been awarded the contract to:
#
# - 1. analyse the supplied data;
# - 2. identify potential errors in the data and clean the existing data set;
# - 3. determine if additional features can be added to enrich the data set;
# - 4. build a model that is capable of forecasting the three hourly demand shortfalls;
# - 5. evaluate the accuracy of the best machine learning model;
# - 6. determine what features were most important in the model’s prediction decision, and
# - 7. explain the inner working of the model to a non-technical audience.
#
# Formally the problem statement was given to you, the senior data scientist, by your manager via email reads as follow:
#
# > In this project you are tasked to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as `pressure`, `wind speed`, `humidity`, etc. As with all data science projects, the provided features are rarely adequate predictors of the target variable. As such, you are required to perform feature engineering to ensure that you will be able to accurately model Spain's three hourly shortfalls.
#
# On top of this, she has provided you with a starter notebook containing vague explanations of what the main outcomes are.

# %% [markdown]
# # <a id="cont"></a>
#
# ## Table of Contents
#
#
#
# <a href=#one>1. Predict Introduction </a>
#
# <a href=#two>2. Machine Learning Process</a>
#
# <a href=#three>3. Loading Data</a>
#
# <a href=#four>4.  Exploratory Data Analysis (EDA)</a>
#
# <a href=#five>5. Data Processing</a>
#
# <a href=#six>6. Modeling</a>
#
# <a href=#seven>7. Model Performance</a>
#
# <a href=#eight>8. Model Explanations</a>
#
# <a href=#nine>9. Conclusion</a>
#
# <a href=#ten>10. References</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Introduction
# <a href=#cont>Back to Table of Contents</a>
#
# Although it can still be considered a growing field, there is no doubt that there are many benefits to renwable energy resources. These include generating energy that produces no greenhouse gas emissions from fossil fuels and reduces some types of air pollution. Diversifying energy supply and reducing dependence on imported fuels. Creating economic development and jobs in manufacturing, installation, and more (1). Further it has been proven that fossil fuels are not sustaible. It is not surpring then that there has been a steady increase in the adoption of renewable energy sources in recent years.
#
#
# In trying to gain deeper understanding of trends and partterns of the country's renwable energy resources and how they compare with fossil fuels, the Spanish govermemnt initated this project. Wherein we were tasked with predicting the shortfall between the energy generated by means of fossil fuels and various renewable sources.
#
# The spanish goverment has been, over a number of years, been tracking the different energy sources utilised in the country. It is that data we will use in coming up with a machine learning model, that would predict the daily energy shortfall for the govermemnt.
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section you are required to import, and briefly discuss, the libraries that will be used throughout your analysis and modelling. |
#
# ---

# %% [markdown]
# <a id="two"></a>
# ## 2. The Machine Learning Process
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# [2]
# ![image info](https://cdn-images-1.medium.com/max/1600/1*KzmIUYPmxgEHhXX7SlbP4w.jpeg)

# %%
# Libraries for data loading, data manipulation and data visulisation
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os #provides functions for interacting with the operating system
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
#sklearn packages
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error
from math import sqrt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from seaborn import pairplot

from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_predict,cross_val_score, KFold, StratifiedKFold

from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

#Stats packages
from scipy import stats
from scipy.stats import norm, skew #for some statistics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="three"></a>
# ## 3. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section you are required to load the data from the `df_train` file into a DataFrame. |
#
# ---

# %%
# loading train_df and test_df

df_train = pd.read_csv('../data/raw/df_train.csv')
df_train.head(3)
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
#
#    Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# 0                0.0                1.0                 0.0       223.333333
# 1                0.0                1.0                 0.0       221.000000
# 2                0.0                1.0                 0.0       214.333333
#
#    Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# 0              6.333333           42.666667                0.0
# 1              4.000000          139.000000                0.0
# 2              2.000000          326.000000                0.0
#
#    Seville_wind_speed  Barcelona_rain_1h Seville_pressure  Seville_rain_1h  \
# 0            3.333333                0.0             sp25              0.0
# 1            3.333333                0.0             sp25              0.0
# 2            2.666667                0.0             sp25              0.0
#
#    Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# 0             0.0         1036.333333              0.0             0.0
# 1             0.0         1037.333333              0.0             0.0
# 2             0.0         1038.000000              0.0             0.0
#
#    Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0                0.0               0.0              800.0
# 1                0.0               0.0              800.0
# 2                0.0               0.0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0                 800.0      1035.000000               800.0
# 1                 800.0      1035.666667               800.0
# 2                 800.0      1036.000000               800.0
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0        1002.666667        274.254667       971.333333         269.888000
# 1        1004.333333        274.945000       972.666667         271.728333
# 2        1005.333333        278.792000       974.000000         278.008667
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0     269.888000              800.0    274.254667          75.666667
# 1     271.728333              800.0    274.945000          71.000000
# 2     278.008667              800.0    278.792000          65.666667
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0         269.888000          281.013000       265.938000      281.013000
# 1         271.728333          280.561667       266.386667      280.561667
# 2         278.008667          281.583667       272.708667      281.583667
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667   265.938000       265.938000        6715.666667
# 1        274.945000   266.386667       266.386667        4171.666667
# 2        278.792000   272.708667       272.708667        4274.666667

# %%
df_test = pd.read_csv('../data/raw/df_test.csv')
df_test.head(3)
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0        8763  2018-01-01 00:00:00           5.000000           level_8
# 1        8764  2018-01-01 03:00:00           4.666667           level_8
# 2        8765  2018-01-01 06:00:00           2.333333           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             5.000000              87.0        71.333333
# 1             0.0             5.333333              89.0        78.000000
# 2             0.0             5.000000              89.0        89.666667
#
#    Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# 0               20.0           3.000000            0.000000       193.333333
# 1                0.0           3.666667            0.000000       143.333333
# 2                0.0           2.333333            6.666667       130.000000
#
#    Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# 0              4.000000          176.666667                0.0
# 1              4.666667          266.666667                0.0
# 2              4.000000          263.333333                0.0
#
#    Seville_wind_speed  Barcelona_rain_1h Seville_pressure  Seville_rain_1h  \
# 0            1.000000                0.0             sp25              0.0
# 1            0.666667                0.0             sp25              0.0
# 2            0.666667                0.0             sp25              0.0
#
#    Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# 0               0         1017.333333              0.0             0.0
# 1               0         1020.333333              0.0             0.0
# 2               0         1023.000000              0.0             0.0
#
#    Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0                0.0                 0              800.0
# 1                0.0                 0              800.0
# 2                0.0                 0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0            800.000000      1025.666667          800.000000
# 1            800.333333      1026.666667          800.000000
# 2            800.000000      1025.333333          800.333333
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0                NaN        284.483333      1030.000000         287.483333
# 1                NaN        282.483333      1030.333333         284.150000
# 2                NaN        280.816667      1030.666667         282.816667
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0     287.483333              801.0    283.673333          46.333333
# 1     284.150000              721.0    281.673333          53.666667
# 2     282.816667              800.0    280.613333          42.000000
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0         287.483333          287.816667       280.816667      287.356667
# 1         284.150000          284.816667       280.483333      284.190000
# 2         282.816667          284.483333       276.483333      283.150000
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       276.150000   280.380000          286.816667           285.15
# 1       277.816667   281.010000          283.483333           284.15
# 2       276.816667   279.196667          281.816667           282.15
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min
# 0        283.150000   279.866667           279.15
# 1        281.150000   279.193333           278.15
# 2        280.483333   276.340000           276.15

# %% [markdown]
#  <a id="four"></a>
# ## 4. Exploratory Data Analysis (EDA)
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section, you are required to perform an in-depth analysis of all the variables in the DataFrame. |
#
# ---

# %% [markdown]
# #### 4.1. Checking Shape of Datasets

# %%
#function to print out the shape of both train and test datasets
def shape_function(df):
    
    """_summary_

    Args:
        df (DataFrame): prints out the shape of df
    """
    
    observations, features = df.shape
    
    print(f'Observation count in train dataset: {observations}')
    print(f'Feature count in test dataset: {features}\n')
    

shape_function(df_train)
shape_function(df_test)
# Out:
# Observation count in train dataset: 8763
# Feature count in test dataset: 49
#
# Observation count in train dataset: 2920
# Feature count in test dataset: 48

# %%
#Checking percentage of data split between the train and test dataset
def data_split_check(x=df_train.shape, y=df_test.shape):
    print(f'Train Data % = {round(x[0] / (x[0] + y[0])*100, 1)}{"%"}')
    print(f'Test Data % = {round(y[0] / (x[0] + y[0])*100, 1)}{"%"}')

data_split_check()
# Out:
# Train Data % = 75.0%
# Test Data % = 25.0%

# %%
#checking all features in train and test dataset
print(f'Train_dataset columns \n\n{df_train.columns} \n\n\nTest_dataset columns \n\n{df_test.columns}')
# Out:
# Train_dataset columns
#
# Index(['Unnamed: 0', 'time', 'Madrid_wind_speed', 'Valencia_wind_deg',
#        'Bilbao_rain_1h', 'Valencia_wind_speed', 'Seville_humidity',
#        'Madrid_humidity', 'Bilbao_clouds_all', 'Bilbao_wind_speed',
#        'Seville_clouds_all', 'Bilbao_wind_deg', 'Barcelona_wind_speed',
#        'Barcelona_wind_deg', 'Madrid_clouds_all', 'Seville_wind_speed',
#        'Barcelona_rain_1h', 'Seville_pressure', 'Seville_rain_1h',
#        'Bilbao_snow_3h', 'Barcelona_pressure', 'Seville_rain_3h',
#        'Madrid_rain_1h', 'Barcelona_rain_3h', 'Valencia_snow_3h',
#        'Madrid_weather_id', 'Barcelona_weather_id', 'Bilbao_pressure',
#        'Seville_weather_id', 'Valencia_pressure', 'Seville_temp_max',
#        'Madrid_pressure', 'Valencia_temp_max', 'Valencia_temp',
#        'Bilbao_weather_id', 'Seville_temp', 'Valencia_humidity',
#        'Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max',
#        'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp',
#        'Barcelona_temp_min', 'Bilbao_temp_max', 'Seville_temp_min',
#        'Madrid_temp', 'Madrid_temp_min', 'load_shortfall_3h'],
#       dtype='object')
#
#
# Test_dataset columns
#
# Index(['Unnamed: 0', 'time', 'Madrid_wind_speed', 'Valencia_wind_deg',
#        'Bilbao_rain_1h', 'Valencia_wind_speed', 'Seville_humidity',
#        'Madrid_humidity', 'Bilbao_clouds_all', 'Bilbao_wind_speed',
#        'Seville_clouds_all', 'Bilbao_wind_deg', 'Barcelona_wind_speed',
#        'Barcelona_wind_deg', 'Madrid_clouds_all', 'Seville_wind_speed',
#        'Barcelona_rain_1h', 'Seville_pressure', 'Seville_rain_1h',
#        'Bilbao_snow_3h', 'Barcelona_pressure', 'Seville_rain_3h',
#        'Madrid_rain_1h', 'Barcelona_rain_3h', 'Valencia_snow_3h',
#        'Madrid_weather_id', 'Barcelona_weather_id', 'Bilbao_pressure',
#        'Seville_weather_id', 'Valencia_pressure', 'Seville_temp_max',
#        'Madrid_pressure', 'Valencia_temp_max', 'Valencia_temp',
#        'Bilbao_weather_id', 'Seville_temp', 'Valencia_humidity',
#        'Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max',
#        'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp',
#        'Barcelona_temp_min', 'Bilbao_temp_max', 'Seville_temp_min',
#        'Madrid_temp', 'Madrid_temp_min'],
#       dtype='object')

# %%
# Checking for presence of null values in train dataset
df_train.isnull().sum()
# Out:
# Unnamed: 0                 0
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2068
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# Seville_temp               0
# Valencia_humidity          0
# Valencia_temp_min          0
# Barcelona_temp_max         0
# Madrid_temp_max            0
# Barcelona_temp             0
# Bilbao_temp_min            0
# Bilbao_temp                0
# Barcelona_temp_min         0
# Bilbao_temp_max            0
# Seville_temp_min           0
# Madrid_temp                0
# Madrid_temp_min            0
# load_shortfall_3h          0
# dtype: int64

# %%
# Checking for presence of null values in test dataset
df_test.isnull().sum()
# Out:
# Unnamed: 0                0
# time                      0
# Madrid_wind_speed         0
# Valencia_wind_deg         0
# Bilbao_rain_1h            0
# Valencia_wind_speed       0
# Seville_humidity          0
# Madrid_humidity           0
# Bilbao_clouds_all         0
# Bilbao_wind_speed         0
# Seville_clouds_all        0
# Bilbao_wind_deg           0
# Barcelona_wind_speed      0
# Barcelona_wind_deg        0
# Madrid_clouds_all         0
# Seville_wind_speed        0
# Barcelona_rain_1h         0
# Seville_pressure          0
# Seville_rain_1h           0
# Bilbao_snow_3h            0
# Barcelona_pressure        0
# Seville_rain_3h           0
# Madrid_rain_1h            0
# Barcelona_rain_3h         0
# Valencia_snow_3h          0
# Madrid_weather_id         0
# Barcelona_weather_id      0
# Bilbao_pressure           0
# Seville_weather_id        0
# Valencia_pressure       454
# Seville_temp_max          0
# Madrid_pressure           0
# Valencia_temp_max         0
# Valencia_temp             0
# Bilbao_weather_id         0
# Seville_temp              0
# Valencia_humidity         0
# Valencia_temp_min         0
# Barcelona_temp_max        0
# Madrid_temp_max           0
# Barcelona_temp            0
# Bilbao_temp_min           0
# Bilbao_temp               0
# Barcelona_temp_min        0
# Bilbao_temp_max           0
# Seville_temp_min          0
# Madrid_temp               0
# Madrid_temp_min           0
# dtype: int64

# %%
# Feature statistics for train dataset
df_train.describe()
# Out:
#         Unnamed: 0  Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# count  8763.000000        8763.000000     8763.000000          8763.000000
# mean   4381.000000           2.425729        0.135753             2.586272
# std    2529.804538           1.850371        0.374901             2.411190
# min       0.000000           0.000000        0.000000             0.000000
# 25%    2190.500000           1.000000        0.000000             1.000000
# 50%    4381.000000           2.000000        0.000000             1.666667
# 75%    6571.500000           3.333333        0.100000             3.666667
# max    8762.000000          13.000000        3.000000            52.000000
#
#        Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# count       8763.000000      8763.000000        8763.000000
# mean          62.658793        57.414717          43.469132
# std           22.621226        24.335396          32.551044
# min            8.333333         6.333333           0.000000
# 25%           44.333333        36.333333          10.000000
# 50%           65.666667        58.000000          45.000000
# 75%           82.000000        78.666667          75.000000
# max          100.000000       100.000000         100.000000
#
#        Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# count        8763.000000         8763.000000      8763.000000
# mean            1.850356           13.714748       158.957511
# std             1.695888           24.272482       102.056299
# min             0.000000            0.000000         0.000000
# 25%             0.666667            0.000000        73.333333
# 50%             1.000000            0.000000       147.000000
# 75%             2.666667           20.000000       234.000000
# max            12.666667           97.333333       359.333333
#
#        Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# count           8763.000000         8763.000000        8763.000000
# mean               2.870497          190.544848          19.473392
# std                1.792197           89.077337          28.053660
# min                0.000000            0.000000           0.000000
# 25%                1.666667          118.166667           0.000000
# 50%                2.666667          200.000000           0.000000
# 75%                4.000000          260.000000          33.333333
# max               12.666667          360.000000         100.000000
#
#        Seville_wind_speed  Barcelona_rain_1h  Seville_rain_1h  Bilbao_snow_3h  \
# count         8763.000000        8763.000000      8763.000000     8763.000000
# mean             2.425045           0.128906         0.039439        0.031912
# std              1.672895           0.634730         0.175857        0.557264
# min              0.000000           0.000000         0.000000        0.000000
# 25%              1.000000           0.000000         0.000000        0.000000
# 50%              2.000000           0.000000         0.000000        0.000000
# 75%              3.333333           0.000000         0.000000        0.000000
# max             11.666667          12.000000         3.000000       21.300000
#
#        Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
#  17  Seville_pressure      8763 non-null   object
#  18  Seville_rain_1h       8763 non-null   float64
#  19  Bilbao_snow_3h        8763 non-null   float64
#  20  Barcelona_pressure    8763 non-null   float64
#  21  Seville_rain_3h       8763 non-null   float64
#  22  Madrid_rain_1h        8763 non-null   float64
#  23  Barcelona_rain_3h     8763 non-null   float64
#  24  Valencia_snow_3h      8763 non-null   float64
#  25  Madrid_weather_id     8763 non-null   float64
#  26  Barcelona_weather_id  8763 non-null   float64
#  27  Bilbao_pressure       8763 non-null   float64
#  28  Seville_weather_id    8763 non-null   float64
#  29  Valencia_pressure     6695 non-null   float64
#  30  Seville_temp_max      8763 non-null   float64
#  31  Madrid_pressure       8763 non-null   float64
#  32  Valencia_temp_max     8763 non-null   float64
#  33  Valencia_temp         8763 non-null   float64
#  34  Bilbao_weather_id     8763 non-null   float64
#  35  Seville_temp          8763 non-null   float64
#  36  Valencia_humidity     8763 non-null   float64
#  37  Valencia_temp_min     8763 non-null   float64
#  38  Barcelona_temp_max    8763 non-null   float64
#  39  Madrid_temp_max       8763 non-null   float64
#  40  Barcelona_temp        8763 non-null   float64
#  41  Bilbao_temp_min       8763 non-null   float64
#  42  Bilbao_temp           8763 non-null   float64
#  43  Barcelona_temp_min    8763 non-null   float64
#  44  Bilbao_temp_max       8763 non-null   float64
#  45  Seville_temp_min      8763 non-null   float64
#  46  Madrid_temp           8763 non-null   float64
#  47  Madrid_temp_min       8763 non-null   float64
#  48  load_shortfall_3h     8763 non-null   float64
# dtypes: float64(45), int64(1), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# #### 4.2. Checking and visualising distribution and Skewness

# %%
from scipy.stats import skew, skewtest, norm
from scipy.stats import kurtosis

# %%
#Visualising distribution of all Target Variable
df_train['load_shortfall_3h'].hist(figsize=(8,5), bins=30)
# Out:
# <AxesSubplot:>

# %%
#checking the distribution
plt.figure(figsize=(8, 5))
sns.distplot(df_train['load_shortfall'], fit=norm)
plt.title('Distribution of load_shortfall')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'load_shortfall'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [192], in <cell line: 3>()
#       1 #checking the distribution
#       2 plt.figure(figsize=(8, 5))
# ----> 3 sns.distplot(df_train['load_shortfall'], fit=norm)
#       4 plt.title('Distribution of load_shortfall')
#       5 plt.show()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'load_shortfall'

# %%
plt.figure(figsize=(4, 5))
sns.boxplot(data=df_train['load_shortfall_3h'], orient='v').set(
    title='Boxplot for load_shortfall_3h')
# Out:
# [Text(0.5, 1.0, 'Boxplot for load_shortfall_3h')]

# %%
print("Skew of raw data: %f" % df_train['load_shortfall_3h'].skew())  # check skewness
print("Kurtosis of raw data: %f" % kurtosis(df_train['load_shortfall_3h'],fisher = False)) #check kurtosis
# Out:
# Skew of raw data: -0.384847
# Kurtosis of raw data: 2.880384

# %%
col_names = df_train.columns

categorical_features = df_train[['Seville_pressure', 'Valencia_wind_deg', 'time']]
numerical_features = [x for x in col_names if not x in categorical_features]

# %%
#Visualising distribution of numerical features
df_train[numerical_features].hist(figsize=(30, 30), bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Madrid_wind_speed'}>,
#         <AxesSubplot:title={'center':'Bilbao_rain_1h'}>,
#         <AxesSubplot:title={'center':'Valencia_wind_speed'}>,
#         <AxesSubplot:title={'center':'Seville_humidity'}>,
#         <AxesSubplot:title={'center':'Madrid_humidity'}>,
#         <AxesSubplot:title={'center':'Bilbao_clouds_all'}>],
#        [<AxesSubplot:title={'center':'Bilbao_wind_speed'}>,
#         <AxesSubplot:title={'center':'Seville_clouds_all'}>,
#         <AxesSubplot:title={'center':'Bilbao_wind_deg'}>,
#         <AxesSubplot:title={'center':'Barcelona_wind_speed'}>,
#         <AxesSubplot:title={'center':'Barcelona_wind_deg'}>,
#         <AxesSubplot:title={'center':'Madrid_clouds_all'}>,
#         <AxesSubplot:title={'center':'Seville_wind_speed'}>],
#        [<AxesSubplot:title={'center':'Barcelona_rain_1h'}>,
#         <AxesSubplot:title={'center':'Seville_rain_1h'}>,
#         <AxesSubplot:title={'center':'Bilbao_snow_3h'}>,
#         <AxesSubplot:title={'center':'Barcelona_pressure'}>,
#         <AxesSubplot:title={'center':'Seville_rain_3h'}>,
#         <AxesSubplot:title={'center':'Madrid_rain_1h'}>,
#         <AxesSubplot:title={'center':'Barcelona_rain_3h'}>],
#        [<AxesSubplot:title={'center':'Valencia_snow_3h'}>,
#         <AxesSubplot:title={'center':'Madrid_weather_id'}>,
#         <AxesSubplot:title={'center':'Barcelona_weather_id'}>,
#         <AxesSubplot:title={'center':'Bilbao_pressure'}>,
#         <AxesSubplot:title={'center':'Seville_weather_id'}>,
#         <AxesSubplot:title={'center':'Valencia_pressure'}>,
#         <AxesSubplot:title={'center':'Seville_temp_max'}>],
#        [<AxesSubplot:title={'center':'Madrid_pressure'}>,
#         <AxesSubplot:title={'center':'Valencia_temp_max'}>,
#         <AxesSubplot:title={'center':'Valencia_temp'}>,
#         <AxesSubplot:title={'center':'Bilbao_weather_id'}>,
#         <AxesSubplot:title={'center':'Seville_temp'}>,
#         <AxesSubplot:title={'center':'Valencia_humidity'}>,
#         <AxesSubplot:title={'center':'Valencia_temp_min'}>],
#        [<AxesSubplot:title={'center':'Barcelona_temp_max'}>,
#         <AxesSubplot:title={'center':'Madrid_temp_max'}>,
#         <AxesSubplot:title={'center':'Barcelona_temp'}>,
#         <AxesSubplot:title={'center':'Bilbao_temp_min'}>,
#         <AxesSubplot:title={'center':'Bilbao_temp'}>,
#         <AxesSubplot:title={'center':'Barcelona_temp_min'}>,
#         <AxesSubplot:title={'center':'Bilbao_temp_max'}>],
#        [<AxesSubplot:title={'center':'Seville_temp_min'}>,
#         <AxesSubplot:title={'center':'Madrid_temp'}>,
#         <AxesSubplot:title={'center':'Madrid_temp_min'}>,
#         <AxesSubplot:title={'center':'load_shortfall_3h'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
#Function to check skewness
def describe_skewness(x):
    if (x > -0.5) and (x < 0.5):
        skewness = 'Fairly Symmetrical'
    elif (x > -1) and (x < -0.5):
        skewness = 'Moderate Negative Skew'
    elif (x > 0.5) and (x < 1):
        skewness = 'Moderate Positive Skew'
    elif x < -1:
        skewness = 'High Negative Skew'
    elif x > 1:
        skewness = 'High Positve Skew'
    return skewness

# %%
# Tabulating Skewness of the numerical features and using a function call to explicitly describe each skewness

data_skew = df_train[numerical_features].skew()
skew_df = pd.DataFrame(
    {'Feature': data_skew.index, 'Skewness': data_skew.values})
skewdf_sorted = skew_df.sort_values(
    'Skewness').reset_index().drop('index', axis=1)
skewdf_sorted['Skewness Description'] = skewdf_sorted['Skewness'].apply(
    describe_skewness)
skewdf_sorted
# Out:
#                  Feature   Skewness    Skewness Description
# 0     Seville_weather_id  -3.275574      High Negative Skew
# 1      Madrid_weather_id  -3.107722      High Negative Skew
# 2   Barcelona_weather_id  -2.584011      High Negative Skew
# 3        Madrid_pressure  -1.850768      High Negative Skew
# 4      Valencia_pressure  -1.705162      High Negative Skew
# 5      Bilbao_weather_id  -1.234844      High Negative Skew
# 6        Bilbao_pressure  -0.999642  Moderate Negative Skew
# 7      load_shortfall_3h  -0.384847      Fairly Symmetrical
# 8       Seville_humidity  -0.310175      Fairly Symmetrical
# 9      Valencia_humidity  -0.305757      Fairly Symmetrical
# 10    Barcelona_wind_deg  -0.180001      Fairly Symmetrical
# 11       Madrid_humidity  -0.057378      Fairly Symmetrical
# 12     Bilbao_clouds_all  -0.053085      Fairly Symmetrical
# 13      Seville_temp_max  -0.033931      Fairly Symmetrical
# 14    Barcelona_temp_min  -0.018057      Fairly Symmetrical
# 15            Unnamed: 0   0.000000      Fairly Symmetrical
# 16         Valencia_temp   0.057476      Fairly Symmetrical
# 17     Valencia_temp_min   0.081832      Fairly Symmetrical
# 18     Valencia_temp_max   0.082672      Fairly Symmetrical
# 19        Barcelona_temp   0.128095      Fairly Symmetrical
# 20          Seville_temp   0.157238      Fairly Symmetrical
# 21       Bilbao_temp_min   0.194912      Fairly Symmetrical
# 22       Bilbao_wind_deg   0.226927      Fairly Symmetrical
# 23      Seville_temp_min   0.265482      Fairly Symmetrical
# 24       Madrid_temp_min   0.275083      Fairly Symmetrical
# 25    Barcelona_temp_max   0.276925      Fairly Symmetrical
# 26           Bilbao_temp   0.293686      Fairly Symmetrical
# 27       Madrid_temp_max   0.298707      Fairly Symmetrical
# 28           Madrid_temp   0.304123      Fairly Symmetrical
# 29       Bilbao_temp_max   0.393932      Fairly Symmetrical
# 30  Barcelona_wind_speed   1.057331       High Positve Skew
# 31    Seville_wind_speed   1.151006       High Positve Skew
# 32     Madrid_clouds_all   1.246745       High Positve Skew
# 33     Madrid_wind_speed   1.441144       High Positve Skew
# 34     Bilbao_wind_speed   1.716914       High Positve Skew
# 35    Seville_clouds_all   1.814452       High Positve Skew
# 36   Valencia_wind_speed   3.499637       High Positve Skew
# 37        Bilbao_rain_1h   5.222802       High Positve Skew
# 38        Madrid_rain_1h   7.074308       High Positve Skew
# 39       Seville_rain_1h   8.067341       High Positve Skew
# 40     Barcelona_rain_1h   8.726988       High Positve Skew
# 41     Barcelona_rain_3h  12.696605       High Positve Skew
# 42       Seville_rain_3h  19.342574       High Positve Skew
# 43        Bilbao_snow_3h  26.177568       High Positve Skew
# 44    Barcelona_pressure  57.979664       High Positve Skew
# 45      Valencia_snow_3h  63.298084       High Positve Skew

# %%
# Funtion to plot a histogram and Box Plot to visualize Distribution and Outliers features
def plot_features(df, feature):
    plt.figure(figsize=(14, 1.5))
    plt.suptitle(feature)

    #plot histogram
    plt.subplot(1, 2, 1)
    plt.hist(df[feature], alpha=0.5)
    #plot boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(df[feature])
    plt.show()


#positive_skewed = []
## Need to write a function later to take care of the function call

# %%
#Visualising the Distribution and Outliers in Positively Skewed Dataset
plot_features(df_train, 'Barcelona_wind_speed')
plot_features(df_train, 'Seville_wind_speed')
plot_features(df_train, 'Bilbao_wind_speed')
plot_features(df_train, 'Valencia_wind_speed')
plot_features(df_train, 'Madrid_wind_speed')
plot_features(df_train, 'Madrid_clouds_all')
plot_features(df_train, 'Seville_clouds_all')
plot_features(df_train, 'Barcelona_pressure')
plot_features(df_train, 'Bilbao_rain_1h')
plot_features(df_train, 'Madrid_rain_1h')
plot_features(df_train, 'Seville_rain_1h')
plot_features(df_train, 'Barcelona_rain_1h')
plot_features(df_train, 'Barcelona_rain_3h')
plot_features(df_train, 'Seville_rain_3h')
plot_features(df_train, 'Bilbao_snow_3h')
plot_features(df_train, 'Valencia_snow_3h')

# %%
#Visualising the Distribution and Outliers in Negatively Skewed Dataset
plot_features(df_train, 'Seville_weather_id')
plot_features(df_train, 'Madrid_weather_id')
plot_features(df_train, 'Barcelona_weather_id')
plot_features(df_train, 'Madrid_pressure')
plot_features(df_train, 'Valencia_pressure')
plot_features(df_train, 'Bilbao_weather_id')
plot_features(df_train, 'Bilbao_pressure')

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Processing
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section, you are required to perform an in-depth analysis of all the variables in the DataFrame. |
#
# ---

# %% [markdown]
# ## 4.1. Exploratory Data Analysis

# %%
# look at data statistics
sns.distplot(df_train['load_shortfall_3h'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df_train['load_shortfall_3h'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('load_shortfall_3h distribution')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df_train['load_shortfall_3h'], plot=plt)
plt.show()
# Out:
#  mu = 10673.86 and sigma = 5217.75

# %%
print(skew(df_train['load_shortfall_3h']))
# Out:
# -0.3847811918590848

# %% [markdown]
# <a id="five"></a>
# ## 5. Data Processing
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section you are required to: clean the dataset, and possibly create new features - as identified in the EDA phase. |
#
# ---

# %% [markdown]
# #### 5.1. Data Cleaning

# %%
df_train_eng = df_train.copy()
df_test_eng = df_test.copy()

# %%
"""This seems redundent. We've already done this in 4.1 above"""

# remove missing values/ features
# Checking for null values
#df_train_eng.isnull().sum()
# Out:
# "This seems redundent. We've already done this in 4.1 above"

# %%
plt.figure(figsize=(4, 5))
sns.boxplot(data=df_train_eng['Valencia_pressure'], orient='v').set(
    title='Valencia_pressure Boxplot')
# Out:
# [Text(0.5, 1.0, 'Valencia_pressure Boxplot')]

# %%
#checking the percent of Null values in Valencia_pressure
def Valencia_pressure_null_Percentange(x=df_train_eng['Valencia_pressure']):
    print(f'Valencia_pressure Null Percentange = {round(x.isnull().sum() / x.notnull().count()*100, 1)}{"%"}')

Valencia_pressure_null_Percentange()
# Out:
# Valencia_pressure Null Percentange = 23.6%

# %%
#checking the percent of Null values in Valencia_pressure
def Valencia_pressure_null_Percentange(x=df_test_eng['Valencia_pressure']):
    print(f'Valencia_pressure Null Percentange = {round(x.isnull().sum() / x.notnull().count()*100, 1)}{"%"}')

Valencia_pressure_null_Percentange()
# Out:
# Valencia_pressure Null Percentange = 15.5%

# %%
# Summary Statistics of Valencia_pressure
def Valencia_pressure_summary(x=df_train_eng['Valencia_pressure']):
    """_summary_

    Args:
        x (Dataframe series): Finds the mean mode and the median of args 
        and prints is out. Defaults to df_train_eng['Valencia_pressure'].
    """
    print(f' Valencia_pressured median = {x.median()}\n')
    print(f' Valencia_pressured mean = {round(x.mean(),2)}\n')
    print(f' Valencia_pressured mode = {x.mode()[0]}\n')


Valencia_pressure_summary()
# Out:
#  Valencia_pressured median = 1015.0
#
#  Valencia_pressured mean = 1012.05
#
#  Valencia_pressured mode = 1018.0

# %% [markdown]
# #### Imputing null values in the datasets

# %%
# Replace Null Values for Valencia_pressure (train data)
df_train_eng['Valencia_pressure'] = df_train_eng['Valencia_pressure'].fillna(
    df_train_eng['Valencia_pressure'].mode()[0])

# %%
# Replace Null Values for Valencia_pressure (test data)
df_test_eng['Valencia_pressure'] = df_test_eng['Valencia_pressure'].fillna(
    df_test_eng['Valencia_pressure'].mode()[0])

# %%
#Verifying Valencia_pressure null fix
print(df_train_eng['Valencia_pressure'].isnull().sum())
print(df_test_eng['Valencia_pressure'].isnull().sum())
# Out:
# 0
# 0

# %%
# Extract number part from Valencia_wind_deg
df_train_eng['Valencia_wind_deg'] = df_train_eng['Valencia_wind_deg'].str.extract('(\d+)')
df_test_eng['Valencia_wind_deg'] = df_test_eng['Valencia_wind_deg'].str.extract('(\d+)')

# Change Valencia_wind_deg feature type to Numeric
df_train_eng['Valencia_wind_deg'] = pd.to_numeric(
    df_train_eng['Valencia_wind_deg'])
df_test_eng['Valencia_wind_deg'] = pd.to_numeric(
    df_test_eng['Valencia_wind_deg'])

# %%
# Extract number part from Seville_pressure
df_train_eng['Seville_pressure'] = df_train_eng['Seville_pressure'].str.extract('(\d+)')
df_test_eng['Seville_pressure'] = df_test_eng['Seville_pressure'].str.extract('(\d+)')

# Change Seville_pressure feature type to Numeric
df_train_eng['Seville_pressure'] = pd.to_numeric(
    df_train_eng['Seville_pressure'])
df_test_eng['Seville_pressure'] = pd.to_numeric(
    df_test_eng['Seville_pressure'])

# %%
#df_train_eng.info()
"""This is another repetition. We've already done this above"""
# Out:
# "This is another repetition. We've already done this above"

# %%
#Removing the index column "Unnamed' for train dataset
df_train_eng = df_train_eng.drop('Unnamed: 0', axis=1)
df_train_eng.head(1)
# Out:
#                   time  Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# 0  2015-01-01 03:00:00           0.666667                  5             0.0
#
#    Valencia_wind_speed  Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# 0             0.666667         74.333333             64.0                0.0
#
#    Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# 0                1.0                 0.0       223.333333
#
#    Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# 0              6.333333           42.666667                0.0
#
#    Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  \
# 0            3.333333                0.0                25              0.0
#
#    Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# 0             0.0         1036.333333              0.0             0.0
#
#    Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0                0.0               0.0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0                 800.0           1035.0               800.0
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0        1002.666667        274.254667       971.333333            269.888
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0        269.888              800.0    274.254667          75.666667
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0            269.888             281.013          265.938         281.013
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615             281.013       269.338615
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667      265.938          265.938        6715.666667

# %%
#Removing the index column "Unnamed' for test dataset
df_test_eng = df_test_eng.drop('Unnamed: 0', axis=1)
df_test_eng.head(1)
# Out:
#                   time  Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# 0  2018-01-01 00:00:00                5.0                  8             0.0
#
#    Valencia_wind_speed  Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# 0                  5.0              87.0        71.333333               20.0
#
#    Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# 0                3.0                 0.0       193.333333
#
#    Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# 0                   4.0          176.666667                0.0
#
#    Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  \
# 0                 1.0                0.0                25              0.0
#
#    Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# 0               0         1017.333333              0.0             0.0
#
#    Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0                0.0                 0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0                 800.0      1025.666667               800.0
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0             1016.0        284.483333           1030.0         287.483333
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0     287.483333              801.0    283.673333          46.333333
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0         287.483333          287.816667       280.816667      287.356667
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0           276.15       280.38          286.816667           285.15
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min
# 0            283.15   279.866667           279.15

# %%
#Convert index of train dataset to Datetime type
df_train_eng['time'] = pd.to_datetime(df_train_eng['time'])

# %%
#Convert index of test dataset to Datetime type
df_test_eng['time'] = pd.to_datetime(df_test_eng['time'])

# %%
# set time features of both train and test dataframe repective index
df_train_eng = df_train_eng.set_index('time')
df_test_eng = df_test_eng.set_index('time')

# %%
df_train_eng.head(1)
# Out:
#                      Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# time
# 2015-01-01 03:00:00           0.666667                  5             0.0
#
#                      Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# time
# 2015-01-01 03:00:00             0.666667         74.333333             64.0
#
#                      Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# time
# 2015-01-01 03:00:00                0.0                1.0                 0.0
#
#                      Bilbao_wind_deg  Barcelona_wind_speed  \
# time
# 2015-01-01 03:00:00       223.333333              6.333333
#
#                      Barcelona_wind_deg  Madrid_clouds_all  \
# time
# 2015-01-01 03:00:00           42.666667                0.0
#
#                      Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  \
# time
# 2015-01-01 03:00:00            3.333333                0.0                25
#
#                      Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  \
# time
# 2015-01-01 03:00:00              0.0             0.0         1036.333333
#
#                      Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# time
# 2015-01-01 03:00:00              0.0             0.0                0.0
#
#                      Valencia_snow_3h  Madrid_weather_id  \
# time
# 2015-01-01 03:00:00               0.0              800.0
#
#                      Barcelona_weather_id  Bilbao_pressure  \
# time
# 2015-01-01 03:00:00                 800.0           1035.0
#
#                      Seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2015-01-01 03:00:00               800.0        1002.666667        274.254667
#
#                      Madrid_pressure  Valencia_temp_max  Valencia_temp  \
# time
# 2015-01-01 03:00:00       971.333333            269.888        269.888
#
#                      Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# time
# 2015-01-01 03:00:00              800.0    274.254667          75.666667
#
#                      Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# time
# 2015-01-01 03:00:00            269.888             281.013          265.938
#
#                      Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# time
# 2015-01-01 03:00:00         281.013       269.338615   269.338615
#
#                      Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# time
# 2015-01-01 03:00:00             281.013       269.338615        274.254667
#
#                      Madrid_temp  Madrid_temp_min  load_shortfall_3h
# time
# 2015-01-01 03:00:00      265.938          265.938        6715.666667

# %%
df_test_eng.head(1)
# Out:
#             Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# time
# 2018-01-01                5.0                  8             0.0
#
#             Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# time
# 2018-01-01                  5.0              87.0        71.333333
#
#             Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# time
# 2018-01-01               20.0                3.0                 0.0
#
#             Bilbao_wind_deg  Barcelona_wind_speed  Barcelona_wind_deg  \
# time
# 2018-01-01       193.333333                   4.0          176.666667
#
#             Madrid_clouds_all  Seville_wind_speed  Barcelona_rain_1h  \
# time
# 2018-01-01                0.0                 1.0                0.0
#
#             Seville_pressure  Seville_rain_1h  Bilbao_snow_3h  \
# time
# 2018-01-01                25              0.0               0
#
#             Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# time
# 2018-01-01         1017.333333              0.0             0.0
#
#             Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# time
# 2018-01-01                0.0                 0              800.0
#
#             Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# time
# 2018-01-01                 800.0      1025.666667               800.0
#
#             Valencia_pressure  Seville_temp_max  Madrid_pressure  \
# time
# 2018-01-01             1016.0        284.483333           1030.0
#
#             Valencia_temp_max  Valencia_temp  Bilbao_weather_id  Seville_temp  \
# time
# 2018-01-01         287.483333     287.483333              801.0    283.673333
#
#             Valencia_humidity  Valencia_temp_min  Barcelona_temp_max  \
# time
# 2018-01-01          46.333333         287.483333          287.816667
#
#             Madrid_temp_max  Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# time
# 2018-01-01       280.816667      287.356667           276.15       280.38
#
#             Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# time
# 2018-01-01          286.816667           285.15            283.15
#
#             Madrid_temp  Madrid_temp_min
# time
# 2018-01-01   279.866667           279.15

# %%
df_test_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2920 entries, 2018-01-01 00:00:00 to 2018-12-31 21:00:00
# Data columns (total 46 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Madrid_wind_speed     2920 non-null   float64
#  1   Valencia_wind_deg     2920 non-null   int64
#  2   Bilbao_rain_1h        2920 non-null   float64
#  3   Valencia_wind_speed   2920 non-null   float64
#  4   Seville_humidity      2920 non-null   float64
#  5   Madrid_humidity       2920 non-null   float64
#  6   Bilbao_clouds_all     2920 non-null   float64
#  7   Bilbao_wind_speed     2920 non-null   float64
#  8   Seville_clouds_all    2920 non-null   float64
#  9   Bilbao_wind_deg       2920 non-null   float64
#  10  Barcelona_wind_speed  2920 non-null   float64
#  11  Barcelona_wind_deg    2920 non-null   float64
#  12  Madrid_clouds_all     2920 non-null   float64
#  13  Seville_wind_speed    2920 non-null   float64
#  14  Barcelona_rain_1h     2920 non-null   float64
#  15  Seville_pressure      2920 non-null   int64
#  16  Seville_rain_1h       2920 non-null   float64
#  17  Bilbao_snow_3h        2920 non-null   int64
#  18  Barcelona_pressure    2920 non-null   float64
#  19  Seville_rain_3h       2920 non-null   float64
#  20  Madrid_rain_1h        2920 non-null   float64
#  21  Barcelona_rain_3h     2920 non-null   float64
#  22  Valencia_snow_3h      2920 non-null   int64
#  23  Madrid_weather_id     2920 non-null   float64
#  24  Barcelona_weather_id  2920 non-null   float64
#  25  Bilbao_pressure       2920 non-null   float64
#  26  Seville_weather_id    2920 non-null   float64
#  27  Valencia_pressure     2920 non-null   float64
#  28  Seville_temp_max      2920 non-null   float64
#  29  Madrid_pressure       2920 non-null   float64
#  30  Valencia_temp_max     2920 non-null   float64
#  31  Valencia_temp         2920 non-null   float64
#  32  Bilbao_weather_id     2920 non-null   float64
#  33  Seville_temp          2920 non-null   float64
#  34  Valencia_humidity     2920 non-null   float64
#  35  Valencia_temp_min     2920 non-null   float64
#  36  Barcelona_temp_max    2920 non-null   float64
#  37  Madrid_temp_max       2920 non-null   float64
#  38  Barcelona_temp        2920 non-null   float64
#  39  Bilbao_temp_min       2920 non-null   float64
#  40  Bilbao_temp           2920 non-null   float64
#  41  Barcelona_temp_min    2920 non-null   float64
#  42  Bilbao_temp_max       2920 non-null   float64
#  43  Seville_temp_min      2920 non-null   float64
#  44  Madrid_temp           2920 non-null   float64
#  45  Madrid_temp_min       2920 non-null   float64
# dtypes: float64(42), int64(4)
# memory usage: 1.0 MB

# %%
# Function that adds new time series features base on datetime index
def new_time_features(df):
    """_summary_

    Args:
        df (Dataframe): pandas dataframe with type Datetime  as index

    Returns:
        Dataframe: with 8 new additional features bases on time series index
    """

    df['Year'] = df.index.year
    df['Quarter'] = df.index.quarter
    df['Month'] = df.index.month
    df['Week'] = df.index.week
    df['Day_of_week'] = df.index.dayofweek
    df['Day_of_year'] = df.index.dayofyear
    df['Year'] = df.index.year
    df['Hour'] = df.index.hour

    return df


#Creating new time series features for both train and test dataset with a function call


df_train_eng = new_time_features(df_train_eng)
df_test_eng = new_time_features(df_test_eng)

# %%
df_test_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2920 entries, 2018-01-01 00:00:00 to 2018-12-31 21:00:00
# Data columns (total 53 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Madrid_wind_speed     2920 non-null   float64
#  1   Valencia_wind_deg     2920 non-null   int64
#  2   Bilbao_rain_1h        2920 non-null   float64
#  3   Valencia_wind_speed   2920 non-null   float64
#  4   Seville_humidity      2920 non-null   float64
#  5   Madrid_humidity       2920 non-null   float64
#  6   Bilbao_clouds_all     2920 non-null   float64
#  7   Bilbao_wind_speed     2920 non-null   float64
#  8   Seville_clouds_all    2920 non-null   float64
#  9   Bilbao_wind_deg       2920 non-null   float64
#  10  Barcelona_wind_speed  2920 non-null   float64
#  11  Barcelona_wind_deg    2920 non-null   float64
#  12  Madrid_clouds_all     2920 non-null   float64
#  13  Seville_wind_speed    2920 non-null   float64
#  14  Barcelona_rain_1h     2920 non-null   float64
#  15  Seville_pressure      2920 non-null   int64
#  16  Seville_rain_1h       2920 non-null   float64
#  17  Bilbao_snow_3h        2920 non-null   int64
#  18  Barcelona_pressure    2920 non-null   float64
#  19  Seville_rain_3h       2920 non-null   float64
#  20  Madrid_rain_1h        2920 non-null   float64
#  21  Barcelona_rain_3h     2920 non-null   float64
#  22  Valencia_snow_3h      2920 non-null   int64
#  23  Madrid_weather_id     2920 non-null   float64
#  24  Barcelona_weather_id  2920 non-null   float64
#  25  Bilbao_pressure       2920 non-null   float64
#  26  Seville_weather_id    2920 non-null   float64
#  27  Valencia_pressure     2920 non-null   float64
#  28  Seville_temp_max      2920 non-null   float64
#  29  Madrid_pressure       2920 non-null   float64
#  30  Valencia_temp_max     2920 non-null   float64
#  31  Valencia_temp         2920 non-null   float64
#  32  Bilbao_weather_id     2920 non-null   float64
#  33  Seville_temp          2920 non-null   float64
#  34  Valencia_humidity     2920 non-null   float64
#  35  Valencia_temp_min     2920 non-null   float64
#  36  Barcelona_temp_max    2920 non-null   float64
#  37  Madrid_temp_max       2920 non-null   float64
#  38  Barcelona_temp        2920 non-null   float64
#  39  Bilbao_temp_min       2920 non-null   float64
#  40  Bilbao_temp           2920 non-null   float64
#  41  Barcelona_temp_min    2920 non-null   float64
#  42  Bilbao_temp_max       2920 non-null   float64
#  43  Seville_temp_min      2920 non-null   float64
#  44  Madrid_temp           2920 non-null   float64
#  45  Madrid_temp_min       2920 non-null   float64
#  46  Year                  2920 non-null   int64
#  47  Quarter               2920 non-null   int64
#  48  Month                 2920 non-null   int64
#  49  Week                  2920 non-null   int64
#  50  Day_of_week           2920 non-null   int64
#  51  Day_of_year           2920 non-null   int64
#  52  Hour                  2920 non-null   int64
# dtypes: float64(42), int64(11)
# memory usage: 1.2 MB

# %%
# Correlations of regressor and the regressand
corrs = df_train_eng[df_train_eng['load_shortfall_3h'].notnull()].corr()['load_shortfall_3h'].sort_values(ascending=False)

# %%
#Checking correlations of each regressor and the regressand

from scipy.stats import pearsonr

# Dictionary to pair the coefficients and p-values
my_dict = {}

col_titles = [x for x in corrs.index if x!= 'load_shortfall_3h']
for x in col_titles:
    p_val = round(pearsonr(df_train_eng[df_train_eng['load_shortfall_3h'].notnull(
    )][x], df_train_eng[df_train_eng['load_shortfall_3h'].notnull()]['load_shortfall_3h'])[1], 6)
    my_dict[x] = {'Correlation_Coefficient': corrs[x], 'P_Value': p_val}

my_dict = pd.DataFrame(my_dict).T
my_dict = my_dict.sort_values('P_Value')
my_dict[my_dict['P_Value'] < 0.1]
# Out:
#                       Correlation_Coefficient   P_Value
# Quarter                              0.210551  0.000000
# Valencia_pressure                    0.090405  0.000000
# Barcelona_weather_id                 0.063868  0.000000
# Seville_weather_id                   0.061104  0.000000
# Seville_humidity                    -0.167290  0.000000
# Barcelona_rain_1h                   -0.056633  0.000000
# Bilbao_wind_speed                   -0.081602  0.000000
# Madrid_clouds_all                   -0.081623  0.000000
# Seville_clouds_all                  -0.091804  0.000000
# Barcelona_wind_speed                -0.103633  0.000000
# Barcelona_wind_deg                  -0.116133  0.000000
# Bilbao_wind_deg                     -0.120800  0.000000
# Bilbao_clouds_all                   -0.127293  0.000000
# Valencia_wind_speed                 -0.142791  0.000000
# Madrid_humidity                     -0.150536  0.000000
# Madrid_wind_speed                   -0.150981  0.000000
# Bilbao_rain_1h                      -0.152510  0.000000
# Day_of_week                         -0.156510  0.000000
# Madrid_pressure                      0.092638  0.000000
# Seville_temp_max                     0.109834  0.000000
# Valencia_wind_deg                   -0.188674  0.000000
# Hour                                 0.139285  0.000000
# Seville_temp_min                     0.174718  0.000000
# Valencia_temp                        0.173225  0.000000
# Year                                 0.131324  0.000000
# Bilbao_temp_max                      0.180934  0.000000
# Madrid_temp_max                      0.182548  0.000000
# Barcelona_temp                       0.182673  0.000000
# Madrid_temp                          0.186036  0.000000
# Madrid_temp_min                      0.174744  0.000000
# Barcelona_temp_min                   0.195984  0.000000
# Week                                 0.201080  0.000000
# Valencia_temp_min                    0.201863  0.000000
# Day_of_year                          0.205528  0.000000
# Bilbao_temp_min                      0.172920  0.000000
# Barcelona_temp_max                   0.164734  0.000000
# Seville_temp                         0.159343  0.000000
# Bilbao_weather_id                    0.145875  0.000000
# Valencia_temp_max                    0.144270  0.000000
# Month                                0.199048  0.000000
# Bilbao_temp                          0.176411  0.000000
# Seville_wind_speed                  -0.048433  0.000006
# Valencia_humidity                    0.043140  0.000054
# Bilbao_pressure                      0.039052  0.000256
# Barcelona_pressure                  -0.034385  0.001285
# Seville_rain_3h                     -0.032945  0.002040
# Bilbao_snow_3h                      -0.031721  0.002981
# Seville_rain_1h                     -0.031572  0.003118
# Madrid_weather_id                    0.030868  0.003854
# Seville_pressure                    -0.030434  0.004383
# Madrid_rain_1h                      -0.027159  0.011008
# Barcelona_rain_3h                   -0.024720  0.020665
# Valencia_snow_3h                    -0.021633  0.042863

# %% [markdown]
# Above shows that each features has a significant importance

# %% [markdown]
# ### Checking and Fixing Multicollinearity

# %% [markdown]
# #### Fixing Skewness

# %%
from scipy.stats import skew, skewtest, norm
import scipy.stats as st
from scipy.stats import kurtosis
from scipy.stats import boxcox
from sklearn.preprocessing import PowerTransformer

# %%
#Selecting Predictors or Target variables.
X = df_train_eng.drop(columns='load_shortfall_3h', axis=1)
y = df_train_eng['load_shortfall_3h']
Y = df_train_eng.load_shortfall_3h.values

# %%
# splitting data df_train into trian and test datasets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state= 100)

# %%
#Investigating train and test splits
print(f'X_train : {X_train.shape}')
print(f'y_train : {y_train.shape}\n')
print(f'X_test : {X_test.shape}')
print(f'y_test : {y_test.shape}')
# Out:
# X_train : (7010, 53)
# y_train : (7010,)
#
# X_test : (1753, 53)
# y_test : (1753,)

# %% [markdown]
# ### Multicollinearity Analysis with Pearson Correlation

# %%
### #Check correlation of regressors
X_train.corr()
# Out:
#                       Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# Madrid_wind_speed              1.000000           0.119749        0.263512
# Valencia_wind_deg              0.119749           1.000000        0.203565
# Bilbao_rain_1h                 0.263512           0.203565        1.000000
# Valencia_wind_speed            0.514627           0.287855        0.258237
# Seville_humidity              -0.120415           0.231324        0.065339
# Madrid_humidity               -0.137936           0.247481        0.101182
# Bilbao_clouds_all              0.247265           0.158134        0.365458
# Bilbao_wind_speed              0.373528           0.073522        0.090146
# Seville_clouds_all             0.194954           0.088612        0.091368
# Bilbao_wind_deg                0.269960           0.157853        0.276515
# Barcelona_wind_speed           0.295836           0.043511        0.064797
# Barcelona_wind_deg            -0.094359           0.152150       -0.029989
# Madrid_clouds_all              0.231252           0.101713        0.131971
# Seville_wind_speed             0.434009          -0.010245        0.134982
# Barcelona_rain_1h              0.068995          -0.005041        0.056792
# Seville_pressure              -0.180652           0.286043        0.072036
# Seville_rain_1h                0.101536          -0.024019        0.082669
# Bilbao_snow_3h                 0.079375           0.073284        0.101182
# Barcelona_pressure             0.010888           0.027951        0.052414
# Seville_rain_3h               -0.000018          -0.022665        0.013663
# Madrid_rain_1h                 0.142262          -0.018021        0.159934
# Barcelona_rain_3h             -0.014854           0.015915       -0.006006
# Valencia_snow_3h               0.026452           0.025485        0.008006
# Madrid_weather_id             -0.165518          -0.004682       -0.137015
# Barcelona_weather_id          -0.102591          -0.009081       -0.120469
# Bilbao_pressure               -0.229775          -0.094327       -0.054156
# Seville_weather_id            -0.113653           0.005571       -0.088936
# Valencia_pressure             -0.193376          -0.155809       -0.231520
# Seville_temp_max               0.054313          -0.327115       -0.197164
# Madrid_pressure               -0.139492          -0.191142       -0.301265
# Valencia_temp_max              0.133228          -0.243210       -0.126486
# Valencia_temp                  0.127921          -0.249620       -0.119750
# Madrid_temp_min               -0.046985           0.019628
# Year                          -0.025419           0.085675
# Quarter                       -0.125061          -0.078717
# Month                         -0.123772          -0.079198
# Week                          -0.126988          -0.068969
# Day_of_week                    0.038224          -0.008504
# Day_of_year                   -0.121128          -0.079654
# Hour                          -0.018555           0.205064
#
#                       Seville_clouds_all  Bilbao_wind_deg  \
# Madrid_wind_speed               0.194954         0.269960
# Valencia_wind_deg               0.088612         0.157853
# Bilbao_rain_1h                  0.091368         0.276515
# Valencia_wind_speed             0.162188         0.240624
# Seville_humidity                0.394296        -0.088266
# Madrid_humidity                 0.369717        -0.068664
# Bilbao_clouds_all               0.059211         0.282904
# Bilbao_wind_speed               0.121933         0.416344
# Seville_clouds_all              1.000000         0.055871
# Bilbao_wind_deg                 0.055871         1.000000
# Barcelona_wind_speed            0.142844         0.172903
# Barcelona_wind_deg             -0.032769        -0.017480
# Madrid_clouds_all               0.546807         0.087061
# Seville_wind_speed              0.147687         0.113704
# Barcelona_rain_1h              -0.000733         0.020789
# Seville_pressure               -0.087887         0.049385
# Seville_rain_1h                 0.408472         0.027298
# Bilbao_snow_3h                  0.005871        -0.038573
# Barcelona_pressure              0.023972         0.035958
# Seville_rain_3h                 0.078107         0.004790
# Madrid_rain_1h                  0.304131         0.048663
# Barcelona_rain_3h               0.030728         0.010846
# Valencia_snow_3h               -0.008685        -0.017998
# Madrid_weather_id              -0.378445        -0.032854
# Barcelona_weather_id           -0.095147        -0.052465
# Bilbao_pressure                -0.331779        -0.105663
# Seville_weather_id             -0.528029        -0.004167
# Valencia_pressure              -0.230665        -0.144476
# Seville_temp_max               -0.177319        -0.076173
# Madrid_pressure                -0.229332        -0.167936
# Valencia_temp_max              -0.183876         0.064719
# Valencia_temp                  -0.181122         0.064596
# Bilbao_weather_id              -0.110176        -0.275839
# Seville_temp                   -0.202938         0.003607
# Valencia_humidity               0.094197        -0.231800
# Valencia_temp_min              -0.172183         0.065069
# Barcelona_temp_max             -0.199871         0.044985
# Madrid_temp_max                -0.234134         0.025275
# Barcelona_temp                 -0.181929         0.064742
# Bilbao_temp_min                -0.126825         0.092395
# Bilbao_temp                    -0.147322         0.062370
# Barcelona_temp_min             -0.149285         0.083331
# Bilbao_temp_max                -0.163232         0.028513
# Seville_temp_min               -0.193812         0.060361
# Madrid_temp                    -0.221763         0.040996
# Madrid_temp_min                -0.206966         0.045552
# Year                           -0.093016        -0.104767
# Quarter                        -0.147452        -0.175368
# Month                          -0.163778        -0.170656
# Week                           -0.137119        -0.162715
# Day_of_week                     0.020697         0.003492
# Day_of_year                    -0.161436        -0.167149
# Hour                           -0.015846         0.114204
#
#                       Barcelona_wind_speed  Barcelona_wind_deg  \
# Madrid_wind_speed                 0.295836           -0.094359
# Valencia_wind_deg                 0.043511            0.152150
# Bilbao_rain_1h                    0.064797           -0.029989
# Valencia_wind_speed               0.344882           -0.063307
# Seville_humidity                 -0.132859            0.160586
# Madrid_humidity                  -0.056056            0.187869
# Bilbao_clouds_all                 0.089978           -0.070066
# Bilbao_wind_speed                 0.276195           -0.014359
# Seville_clouds_all                0.142844           -0.032769
# Bilbao_wind_deg                   0.172903           -0.017480
# Barcelona_wind_speed              1.000000            0.078614
# Barcelona_wind_deg                0.078614            1.000000
# Madrid_clouds_all                 0.151017           -0.043487
# Seville_wind_speed                0.199817           -0.099061
# Barcelona_rain_1h                 0.041979           -0.030809
# Seville_pressure                 -0.115355            0.209660
# Seville_rain_1h                   0.114255           -0.101198
# Bilbao_snow_3h                    0.017606           -0.028427
# Barcelona_pressure                0.001631           -0.000961
# Seville_rain_3h                   0.056609           -0.040439
# Madrid_rain_1h                    0.134369           -0.111182
# Barcelona_rain_3h                 0.003208           -0.012342
# Valencia_snow_3h                  0.029481           -0.024828
# Madrid_weather_id                -0.120769            0.095892
# Barcelona_weather_id             -0.052819            0.149795
# Bilbao_pressure                  -0.081603            0.135483
# Seville_weather_id               -0.096864            0.071735
# Valencia_pressure                -0.087986            0.101519
# Seville_temp_max                  0.152579           -0.087376
# Madrid_pressure                  -0.016024            0.100336
# Valencia_temp_max                 0.136581           -0.175634
# Valencia_temp                     0.119137           -0.206305
# Bilbao_weather_id                -0.065092            0.051457
# Seville_temp                      0.144729           -0.164687
# Valencia_humidity                -0.248951            0.043366
# Valencia_temp_min                 0.094979           -0.232964
# Barcelona_temp_max                0.116698           -0.158696
# Madrid_temp_max                   0.081379           -0.200264
# Barcelona_temp                    0.116629           -0.196985
# Bilbao_temp_min                   0.126669           -0.186732
# Bilbao_temp                       0.123900           -0.167912
# Barcelona_temp_min                0.106939           -0.235065
# Bilbao_temp_max                   0.113155           -0.149144
# Seville_temp_min                  0.125952           -0.200211
# Madrid_temp                       0.086002           -0.218048
# Madrid_temp_min                   0.080246           -0.216472
# Year                             -0.196435           -0.152730
# Quarter                          -0.129216            0.008567
# Month                            -0.124011            0.023158
# Week                             -0.116867            0.030761
# Day_of_week                      -0.007951            0.037054
# Day_of_year                      -0.124732            0.020666
# Hour                              0.184817           -0.187990
#
#                       Madrid_clouds_all  Seville_wind_speed  \
# Madrid_wind_speed              0.231252            0.434009
# Valencia_wind_deg              0.101713           -0.010245
# Bilbao_rain_1h                 0.131971            0.134982
# Valencia_wind_speed            0.217779            0.308954
# Seville_humidity               0.362590           -0.204137
# Madrid_humidity                0.481276           -0.126308
# Bilbao_clouds_all              0.103345            0.079200
# Bilbao_wind_speed              0.251610            0.203078
# Seville_clouds_all             0.546807            0.147687
# Bilbao_wind_deg                0.087061            0.113704
# Barcelona_wind_speed           0.151017            0.199817
# Barcelona_wind_deg            -0.043487           -0.099061
# Madrid_clouds_all              1.000000            0.168774
# Seville_wind_speed             0.168774            1.000000
# Barcelona_rain_1h              0.008759            0.074613
# Seville_pressure              -0.062004           -0.181992
# Seville_rain_1h                0.302395            0.114801
# Bilbao_snow_3h                 0.044126            0.048378
# Barcelona_pressure             0.013157           -0.010761
# Seville_rain_3h                0.068588           -0.003237
# Madrid_rain_1h                 0.403126            0.174150
# Barcelona_rain_3h             -0.000861           -0.017243
# Valencia_snow_3h               0.025996            0.033986
# Madrid_weather_id             -0.531672           -0.188352
# Barcelona_weather_id          -0.120676           -0.053439
# Bilbao_pressure               -0.317843           -0.131659
# Seville_weather_id            -0.374405           -0.139103
# Valencia_pressure             -0.206615           -0.177962
# Seville_temp_max              -0.183245            0.094140
# Madrid_pressure               -0.185455           -0.139890
# Valencia_temp_max             -0.199380            0.101528
# Valencia_temp                 -0.198527            0.104870
# Bilbao_weather_id             -0.171529           -0.115237
# Seville_temp                  -0.235727            0.139476
# Valencia_humidity              0.064316           -0.208824
# Valencia_temp_min             -0.190885            0.105768
# Barcelona_temp_max            -0.242830            0.069391
# Madrid_temp_max               -0.276715            0.101444
# Barcelona_temp                -0.224993            0.085740
# Bilbao_temp_min               -0.162572            0.095498
# Bilbao_temp                   -0.169117            0.083926
# Barcelona_temp_min            -0.190390            0.097667
# Bilbao_temp_max               -0.167751            0.070188
# Seville_temp_min              -0.242555            0.155251
# Madrid_temp                   -0.260469            0.109706
# Madrid_temp_min               -0.243222            0.089300
# Year                          -0.080133           -0.056978
# Quarter                       -0.108728           -0.123393
# Month                         -0.116656           -0.115033
# Week                          -0.095155           -0.116001
# Day_of_week                   -0.002979            0.020356
# Day_of_year                   -0.111776           -0.116986
# Hour                           0.024159            0.252856
#
#                       Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  \
# Madrid_wind_speed              0.068995         -0.180652         0.101536
# Valencia_wind_deg             -0.005041          0.286043        -0.024019
# Bilbao_rain_1h                 0.056792          0.072036         0.082669
# Valencia_wind_speed            0.030452         -0.070489         0.036344
# Seville_humidity              -0.042413          0.221023         0.226249
# Madrid_humidity               -0.058392          0.303581         0.194559
# Bilbao_clouds_all              0.049603         -0.043053         0.050427
# Bilbao_wind_speed             -0.022416         -0.107175         0.072285
# Seville_clouds_all            -0.000733         -0.087887         0.408472
# Bilbao_wind_deg                0.020789          0.049385         0.027298
# Barcelona_wind_speed           0.041979         -0.115355         0.114255
# Barcelona_wind_deg            -0.030809          0.209660        -0.101198
# Madrid_clouds_all              0.008759         -0.062004         0.302395
# Seville_wind_speed             0.074613         -0.181992         0.114801
# Barcelona_rain_1h              1.000000         -0.054837         0.054972
# Seville_pressure              -0.054837          1.000000        -0.184708
# Seville_rain_1h                0.054972         -0.184708         1.000000
# Bilbao_snow_3h                 0.090897          0.030372        -0.006948
# Barcelona_pressure             0.061434          0.021821         0.005404
# Seville_rain_3h               -0.011957         -0.023066        -0.009163
# Madrid_rain_1h                 0.069647         -0.171875         0.340137
# Barcelona_rain_3h             -0.019396          0.024983         0.007445
# Valencia_snow_3h               0.071573          0.004242        -0.003415
# Madrid_weather_id             -0.034843          0.150654        -0.337105
# Barcelona_weather_id          -0.522529          0.154859        -0.157926
# Bilbao_pressure               -0.053861          0.269626        -0.167946
# Seville_weather_id            -0.010332          0.187580        -0.691885
# Valencia_pressure             -0.020011          0.000765        -0.102257
# Seville_temp_max               0.058906         -0.514519        -0.081680
# Madrid_pressure               -0.024165         -0.144672        -0.069075
# Valencia_humidity           0.064424           0.003927         -0.018625
# Valencia_temp_min          -0.061095          -0.056188         -0.022738
# Barcelona_temp_max         -0.072337          -0.051342         -0.025516
# Madrid_temp_max            -0.116023          -0.049649         -0.021354
# Barcelona_temp             -0.054792          -0.043285         -0.025302
# Bilbao_temp_min            -0.038184          -0.028228         -0.025465
# Bilbao_temp                -0.052260          -0.044096         -0.028225
# Barcelona_temp_min         -0.029064          -0.030386         -0.023449
# Bilbao_temp_max            -0.064309          -0.059314         -0.030401
# Seville_temp_min           -0.085332          -0.015609         -0.016110
# Madrid_temp                -0.106137          -0.042726         -0.020409
# Madrid_temp_min            -0.096213          -0.032583         -0.018642
# Year                       -0.043942          -0.083055         -0.018873
# Quarter                    -0.058904          -0.061354         -0.020983
# Month                      -0.064463          -0.055362         -0.020307
# Week                       -0.055902          -0.055793         -0.021328
# Day_of_week                -0.001366          -0.039991         -0.007279
# Day_of_year                -0.061956          -0.057477         -0.021761
# Hour                        0.039200           0.002618          0.000481
#
#                       Madrid_weather_id  Barcelona_weather_id  \
# Madrid_wind_speed             -0.165518             -0.102591
# Valencia_wind_deg             -0.004682             -0.009081
# Bilbao_rain_1h                -0.137015             -0.120469
# Valencia_wind_speed           -0.097318             -0.030284
# Seville_humidity              -0.233268             -0.051851
# Madrid_humidity               -0.344762             -0.052365
# Bilbao_clouds_all             -0.077768             -0.123120
# Bilbao_wind_speed             -0.107678             -0.004768
# Seville_clouds_all            -0.378445             -0.095147
# Bilbao_wind_deg               -0.032854             -0.052465
# Barcelona_wind_speed          -0.120769             -0.052819
# Barcelona_wind_deg             0.095892              0.149795
# Madrid_clouds_all             -0.531672             -0.120676
# Seville_wind_speed            -0.188352             -0.053439
# Barcelona_rain_1h             -0.034843             -0.522529
# Seville_pressure               0.150654              0.154859
# Seville_rain_1h               -0.337105             -0.157926
# Bilbao_snow_3h                 0.001528             -0.024862
# Barcelona_pressure             0.004147             -0.015307
# Seville_rain_3h               -0.123296              0.022422
# Madrid_rain_1h                -0.714211             -0.155633
# Barcelona_rain_3h             -0.006632              0.025526
# Valencia_snow_3h               0.005820             -0.014006
# Madrid_weather_id              1.000000              0.135909
# Barcelona_weather_id           0.135909              1.000000
# Bilbao_pressure                0.239591              0.129687
# Seville_weather_id             0.391297              0.127946
# Valencia_pressure              0.161037              0.094671
# Seville_temp_max               0.101315             -0.003919
# Madrid_pressure                0.101929              0.035661
# Valencia_temp_max              0.100348              0.015426
# Valencia_temp                  0.092256              0.027246
# Bilbao_weather_id              0.159572              0.110875
# Seville_temp                   0.119139              0.009967
# Valencia_humidity             -0.091125             -0.099630
# Valencia_temp_min              0.081275              0.040084
# Barcelona_temp_max             0.107480              0.018564
# Madrid_temp_max                0.150195              0.023330
# Barcelona_temp                 0.086992              0.027580
# Bilbao_temp_min                0.057565              0.049991
# Bilbao_temp                    0.070360              0.048800
# Barcelona_temp_min             0.057305              0.041576
# Bilbao_temp_max                0.079016              0.049364
# Seville_temp_min               0.115717              0.016766
#
#                       Valencia_temp  Bilbao_weather_id  Seville_temp  \
# Madrid_wind_speed          0.127921          -0.248953      0.095727
# Valencia_wind_deg         -0.249620          -0.213298     -0.339337
# Bilbao_rain_1h            -0.119750          -0.599336     -0.159151
# Valencia_wind_speed        0.079643          -0.195870      0.003967
# Seville_humidity          -0.662098          -0.098154     -0.739570
# Madrid_humidity           -0.707218          -0.133273     -0.737703
# Bilbao_clouds_all         -0.000869          -0.533670     -0.095656
# Bilbao_wind_speed          0.093049          -0.043188      0.079450
# Seville_clouds_all        -0.181122          -0.110176     -0.202938
# Bilbao_wind_deg            0.064596          -0.275839      0.003607
# Barcelona_wind_speed       0.119137          -0.065092      0.144729
# Barcelona_wind_deg        -0.206305           0.051457     -0.164687
# Madrid_clouds_all         -0.198527          -0.171529     -0.235727
# Seville_wind_speed         0.104870          -0.115237      0.139476
# Barcelona_rain_1h          0.038553          -0.046077      0.061575
# Seville_pressure          -0.407460          -0.062203     -0.470980
# ...
# Year                           -0.031489         0.031781        0.000267
# Quarter                         0.239199         0.197341        0.218665
# Month                           0.232238         0.193276        0.204366
# Week                            0.218455         0.177702        0.188597
# Day_of_week                    -0.015151        -0.008931       -0.009834
# Day_of_year                     0.229191         0.189916        0.201711
# Hour                            0.191011         0.285672        0.219508
#
#                       Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# Madrid_wind_speed            0.080332     0.063436            0.084930
# Valencia_wind_deg           -0.263048    -0.280401           -0.232337
# Bilbao_rain_1h              -0.136291    -0.177258           -0.100819
# Valencia_wind_speed         -0.001356    -0.012859            0.004548
# Seville_humidity            -0.604195    -0.603302           -0.594074
# Madrid_humidity             -0.633874    -0.633120           -0.637902
# Bilbao_clouds_all           -0.071084    -0.118011           -0.012693
# Bilbao_wind_speed            0.106314     0.141744            0.018398
# Seville_clouds_all          -0.126825    -0.147322           -0.149285
# Bilbao_wind_deg              0.092395     0.062370            0.083331
# Barcelona_wind_speed         0.126669     0.123900            0.106939
# Barcelona_wind_deg          -0.186732    -0.167912           -0.235065
# Madrid_clouds_all           -0.162572    -0.169117           -0.190390
# Seville_wind_speed           0.095498     0.083926            0.097667
# Barcelona_rain_1h            0.024155     0.029731            0.020751
# Seville_pressure            -0.328870    -0.353633           -0.351795
# Seville_rain_1h             -0.067700    -0.076368           -0.074454
# Bilbao_snow_3h              -0.085328    -0.095430           -0.077439
# Barcelona_pressure          -0.023769    -0.028973           -0.030712
# Seville_rain_3h             -0.020034    -0.031129           -0.027720
# Madrid_rain_1h              -0.038184    -0.052260           -0.029064
# Barcelona_rain_3h           -0.028228    -0.044096           -0.030386
# Valencia_snow_3h            -0.025465    -0.028225           -0.023449
# Madrid_weather_id            0.057565     0.070360            0.057305
# Barcelona_weather_id         0.049991     0.048800            0.041576
# Bilbao_pressure             -0.273595    -0.255923           -0.232867
# Seville_weather_id           0.123735     0.127595            0.147320
# Valencia_pressure           -0.067771     0.001066           -0.140187
# Seville_temp_max             0.652368     0.703864            0.581215
# Madrid_pressure              0.004641     0.088679           -0.073347
# Valencia_temp_max            0.842008     0.856080            0.843063
# Seville_rain_3h         -0.002926    -0.051111  0.021544
# Madrid_rain_1h          -0.001366    -0.061956  0.039200
# Barcelona_rain_3h       -0.039991    -0.057477  0.002618
# Valencia_snow_3h        -0.007279    -0.021761  0.000481
# Madrid_weather_id       -0.013842     0.065908 -0.029802
# Barcelona_weather_id    -0.036698     0.022415 -0.001197
# Bilbao_pressure         -0.005037     0.008965 -0.017655
# Seville_weather_id      -0.017441     0.096175  0.028065
# Valencia_pressure       -0.021840     0.086242 -0.024848
# Seville_temp_max         0.004469     0.192116  0.235200
# Madrid_pressure         -0.017650     0.264213 -0.011803
# Valencia_temp_max        0.006946     0.211353  0.261257
# Valencia_temp            0.006966     0.216628  0.283658
# Bilbao_weather_id       -0.037524     0.145046 -0.000211
# Seville_temp             0.005514     0.213319  0.329517
# Valencia_humidity       -0.015020     0.161391 -0.359629
# Valencia_temp_min        0.007032     0.219999  0.299363
# Barcelona_temp_max      -0.015151     0.229191  0.191011
# Madrid_temp_max         -0.008931     0.189916  0.285672
# Barcelona_temp          -0.009834     0.201711  0.219508
# Bilbao_temp_min         -0.011870     0.199282  0.279584
# Bilbao_temp             -0.012388     0.243298  0.274083
# Barcelona_temp_min      -0.008024     0.158584  0.243832
# Bilbao_temp_max         -0.012269     0.281542  0.261348
# Seville_temp_min         0.007118     0.204725  0.359951
# Madrid_temp             -0.006629     0.182384  0.292884
# Madrid_temp_min         -0.005480     0.158953  0.270610
# Year                    -0.006394    -0.018311  0.000344
# Quarter                  0.004731     0.968342  0.007187
# Month                    0.002475     0.996496  0.006947
# Week                    -0.002377     0.977391  0.008455
# Day_of_week              1.000000     0.002191  0.001018
# Day_of_year              0.002191     1.000000  0.007367
# Hour                     0.001018     0.007367  1.000000

# %%
#Visualise Correlation Using Pearson Correlation
plt.figure(figsize=(40, 40))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.coolwarm_r)
plt.show()

# %%
#Function to traverse through the correlation Matrix and based on a threshold remove a feature
def correlation(df, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            # we are interested in absolute coeff value
            if abs(corr_matrix.iloc[i, j]) > threshold:
                column_name = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(column_name)
    return col_corr

#https://github.com/krishnaik06/Complete-Feature-Selection/blob/master/2-Feature%20Selection-%20Correlation.ipynb

# %%
to_drop_features = correlation(X_train, 0.90)
len(set(to_drop_features))
# Out:
# 15

# %%
#Features to be dropped based on correlation analysis
to_drop_features
# Out:
# {'Barcelona_temp',
#  'Barcelona_temp_max',
#  'Barcelona_temp_min',
#  'Bilbao_temp',
#  'Bilbao_temp_max',
#  'Day_of_year',
#  'Madrid_temp',
#  'Madrid_temp_max',
#  'Madrid_temp_min',
#  'Month',
#  'Seville_temp',
#  'Seville_temp_min',
#  'Valencia_temp',
#  'Valencia_temp_min',
#  'Week'}

# %%
corr_X_features = X_train.copy()
corr_X_features.drop(['Barcelona_temp',
                        'Barcelona_temp_max',
                        'Barcelona_temp_min',
                        'Bilbao_temp',
                        'Bilbao_temp_max',
                        'Day_of_year',
                        'Madrid_temp',
                        'Madrid_temp_max',
                        'Madrid_temp_min',
                        'Month',
                        'Seville_temp',
                        'Seville_temp_min',
                        'Valencia_temp',
                        'Valencia_temp_min',
                        'Week'], axis=1)
# Out:
#                      Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# time
# 2015-04-01 00:00:00               90.0           1.000000                 0.0
# 2017-06-26 06:00:00               20.0           0.666667                 0.0
#
#                      Bilbao_wind_deg  Barcelona_wind_speed  \
# time
# 2015-04-01 00:00:00       317.333333              1.000000
# 2017-06-26 06:00:00        30.000000              2.333333
#
#                      Barcelona_wind_deg  Madrid_clouds_all  \
# time
# 2015-04-01 00:00:00               163.0                6.0
# 2017-06-26 06:00:00               200.0               40.0
#
#                      Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  \
# time
# 2015-04-01 00:00:00            1.666667                0.0                20
# 2017-06-26 06:00:00            0.666667                0.0                 3
#
#                      Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  \
# time
# 2015-04-01 00:00:00              0.0             0.0         1025.333333
# 2017-06-26 06:00:00              0.0             0.0         1012.333333
#
#                      Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# time
# 2015-04-01 00:00:00              0.0             0.0           0.006667
# 2017-06-26 06:00:00              0.0             0.0           0.000000
#
#                      Valencia_snow_3h  Madrid_weather_id  \
# time
# 2015-04-01 00:00:00               0.0         800.333333
# 2017-06-26 06:00:00               0.0         605.000000
#
#                      Barcelona_weather_id  Bilbao_pressure  \
# time
# 2015-04-01 00:00:00                 800.0      1033.666667
# 2017-06-26 06:00:00                 800.0      1010.000000
#
#                      Seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2015-04-01 00:00:00          800.000000        1018.000000        290.777323
# 2017-06-26 06:00:00          770.333333        1011.333333        293.150000
#
#                      Madrid_pressure  Valencia_temp_max  Valencia_temp  \
# time
# 2015-04-01 00:00:00           1028.0         285.335656     285.335656
# 2017-06-26 06:00:00           1013.0         295.483333     295.483333
#
#                      Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# time
# 2015-04-01 00:00:00              500.0    290.777323               61.0
# 2017-06-26 06:00:00              801.0    292.743333               90.0
#
#                      Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# time
# 2015-04-01 00:00:00         285.335656          285.935667       283.552333
# 2017-06-26 06:00:00         295.483333          296.150000       291.483333
#
#                      Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# time
# 2015-04-01 00:00:00      285.935667          282.969      282.969
# 2017-06-26 06:00:00      295.816667          290.150      291.050
#
#                      Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# time
# 2015-04-01 00:00:00          285.935667          282.969        290.777323
# 2017-06-26 06:00:00          295.483333          292.150        292.483333
#
#                      Madrid_temp  Madrid_temp_min  Year  Quarter  Month  Week  \
# time
# 2015-04-01 00:00:00   283.552333       283.552333  2015        2      4    14
# 2017-06-26 06:00:00   291.073333       290.816667  2017        2      6    26
#
#                      Day_of_week  Day_of_year  Hour
# time
# 2015-04-01 00:00:00            2           91     0
# 2017-06-26 06:00:00            0          177     6

# %%
#The above 15 features were only dropped on the X_train (from split). Not the whole X. It might me a good idea to do it for X to

# %%
X_corr = X.copy()
X_corr.drop(['Barcelona_temp',
                        'Barcelona_temp_max',
                        'Barcelona_temp_min',
                        'Bilbao_temp',
                        'Bilbao_temp_max',
                        'Day_of_year',
                        'Madrid_temp',
                        'Madrid_temp_max',
                        'Madrid_temp_min',
                        'Month',
                        'Seville_temp',
                        'Seville_temp_min',
                        'Valencia_temp',
                        'Valencia_temp_min',
                        'Week'], axis=1)
# Out:
#                      Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2015-01-01 03:00:00          800.000000        1002.666667        274.254667
# 2015-01-01 06:00:00          800.000000        1004.333333        274.945000
# 2015-01-01 09:00:00          800.000000        1005.333333        278.792000
# 2015-01-01 12:00:00          800.000000        1009.000000        285.394000
# 2015-01-01 15:00:00          800.000000        1018.000000        285.513719
# ...                                 ...                ...               ...
# 2017-12-31 09:00:00          769.333333        1018.000000        285.483333
# 2017-12-31 12:00:00          803.000000        1021.000000        288.483333
# 2017-12-31 15:00:00          801.666667        1009.666667        291.483333
# 2017-12-31 18:00:00          802.333333        1020.000000        291.483333
# 2017-12-31 21:00:00          801.666667        1018.000000        289.150000
#
#                      Madrid_pressure  Valencia_temp_max  Bilbao_weather_id  \
# time
# 2015-01-01 03:00:00       971.333333         269.888000         800.000000
# 2015-01-01 06:00:00       972.666667         271.728333         800.000000
# 2015-01-01 09:00:00       974.000000         278.008667         800.000000
# 2015-01-01 12:00:00       994.666667         284.899552         800.000000
# 2015-01-01 15:00:00      1035.333333         283.015115         800.000000
# ...                              ...                ...                ...
# 2017-12-31 09:00:00      1024.000000         282.483333         802.333333
# 2017-12-31 12:00:00      1023.666667         291.816667         801.333333
# 2017-12-31 15:00:00      1021.666667         290.706333         601.000000
# 2017-12-31 18:00:00      1023.000000         290.483333         634.166667
# 2017-12-31 21:00:00      1027.333333         289.483333         801.000000
#
#                      Valencia_humidity  Bilbao_temp_min  Year  Quarter  \
# time
# 2015-01-01 03:00:00          75.666667       269.338615  2015        1
# 2015-01-01 06:00:00          71.000000       270.376000  2015        1
# 2015-01-01 09:00:00          65.666667       275.027229  2015        1
# 2015-01-01 12:00:00          54.000000       281.135063  2015        1
# 2015-01-01 15:00:00          58.333333       282.252063  2015        1
# ...                                ...              ...   ...      ...
# 2017-12-31 09:00:00          71.333333       285.150000  2017        4
# 2017-12-31 12:00:00          40.333333       286.483333  2017        4
# 2017-12-31 15:00:00          44.666667       283.816667  2017        4
# 2017-12-31 18:00:00          45.000000       278.816667  2017        4
# 2017-12-31 21:00:00          50.000000       276.816667  2017        4
#
#                      Day_of_week  Hour
# time
# 2015-01-01 03:00:00            3     3
# 2015-01-01 06:00:00            3     6
# 2015-01-01 09:00:00            3     9
# 2015-01-01 12:00:00            3    12
# 2015-01-01 15:00:00            3    15
# ...                          ...   ...
# 2017-12-31 09:00:00            6     9
# 2017-12-31 12:00:00            6    12
# 2017-12-31 15:00:00            6    15
# 2017-12-31 18:00:00            6    18
# 2017-12-31 21:00:00            6    21
#
# [8763 rows x 38 columns]

# %% [markdown]
# #### The same features dropped for X_train data are dropped for the test dataset

# %%
df_test_eng_corr = df_test_eng.copy()

# %%
df_test_eng_corr = df_test_eng.copy()
df_test_eng_corr.drop(['Barcelona_temp',
                        'Barcelona_temp_max',
                        'Barcelona_temp_min',
                        'Bilbao_temp',
                        'Bilbao_temp_max',
                        'Day_of_year',
                        'Madrid_temp',
                        'Madrid_temp_max',
                        'Madrid_temp_min',
                        'Month',
                        'Seville_temp',
                        'Seville_temp_min',
                        'Valencia_temp',
                        'Valencia_temp_min',
                        'Week'], axis=1)
# Out:
#                      Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2018-01-01 00:00:00          800.000000             1016.0        284.483333
# 2018-01-01 03:00:00          800.000000             1016.0        282.483333
# 2018-01-01 06:00:00          800.333333             1016.0        280.816667
# 2018-01-01 09:00:00          800.333333             1016.0        281.150000
# 2018-01-01 12:00:00          800.000000             1016.0        287.150000
# ...                                 ...                ...               ...
# 2018-12-31 09:00:00          800.000000             1016.0        280.816667
# 2018-12-31 12:00:00          800.000000             1016.0        287.483333
# 2018-12-31 15:00:00          800.000000             1016.0        290.816667
# 2018-12-31 18:00:00          800.000000             1016.0        288.816667
# 2018-12-31 21:00:00          800.000000             1016.0        284.816667
#
#                      Madrid_pressure  Valencia_temp_max  Bilbao_weather_id  \
# time
# 2018-01-01 00:00:00      1030.000000         287.483333         801.000000
# 2018-01-01 03:00:00      1030.333333         284.150000         721.000000
# 2018-01-01 06:00:00      1030.666667         282.816667         800.000000
# 2018-01-01 09:00:00      1032.333333         283.483333         801.333333
# 2018-01-01 12:00:00      1032.333333         287.150000         801.333333
# ...                              ...                ...                ...
# 2018-12-31 09:00:00      1031.666667         279.816667         734.333333
# 2018-12-31 12:00:00      1031.333333         290.816667         747.666667
# 2018-12-31 15:00:00      1030.000000         293.483333         800.000000
# 2018-12-31 18:00:00      1030.333333         286.483333         800.000000
# 2018-12-31 21:00:00      1030.666667         281.150000         800.000000
#
#                      Valencia_humidity  Bilbao_temp_min  Year  Quarter  \
# time
# 2018-01-01 00:00:00          46.333333       276.150000  2018        1
# 2018-01-01 03:00:00          53.666667       277.816667  2018        1
# 2018-01-01 06:00:00          42.000000       276.816667  2018        1
# 2018-01-01 09:00:00          45.000000       279.150000  2018        1
# 2018-01-01 12:00:00          41.000000       281.816667  2018        1
# ...                                ...              ...   ...      ...
# 2018-12-31 09:00:00          69.666667       270.816667  2018        4
# 2018-12-31 12:00:00          32.000000       278.150000  2018        4
# 2018-12-31 15:00:00          23.666667       284.150000  2018        4
# 2018-12-31 18:00:00          59.000000       280.150000  2018        4
# 2018-12-31 21:00:00          79.000000       276.150000  2018        4
#
#                      Day_of_week  Hour
# time
# 2018-01-01 00:00:00            0     0
# 2018-01-01 03:00:00            0     3
# 2018-01-01 06:00:00            0     6
# 2018-01-01 09:00:00            0     9
# 2018-01-01 12:00:00            0    12
# ...                          ...   ...
# 2018-12-31 09:00:00            0     9
# 2018-12-31 12:00:00            0    12
# 2018-12-31 15:00:00            0    15
# 2018-12-31 18:00:00            0    18
# 2018-12-31 21:00:00            0    21
#
# [2920 rows x 38 columns]

# %% [markdown]
# ### Multicollinearity Analysis with Variable Inflation Factor(VIF)

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

#function to check and for each regressor's VIF
def calculate_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["Features"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)


#Tabulate regressors against VIF values
calculate_vif(X_train)


#https://www.analyticsvidhya.com/blog/2020/03/what-is-multicollinearity/
# Out:
#                 Features           VIF
# 0      Madrid_wind_speed  5.339390e+00
# 1      Valencia_wind_deg  6.726062e+00
# 2         Bilbao_rain_1h  2.001361e+00
# 3    Valencia_wind_speed  4.263167e+00
# 4       Seville_humidity  4.809670e+01
# 5        Madrid_humidity  4.268010e+01
# 6      Bilbao_clouds_all  4.553355e+00
# 7      Bilbao_wind_speed  4.109569e+00
# 8     Seville_clouds_all  2.690890e+00
# 9        Bilbao_wind_deg  5.297870e+00
# 10  Barcelona_wind_speed  4.928816e+00
# 11    Barcelona_wind_deg  7.069796e+00
# 12     Madrid_clouds_all  3.324659e+00
# 13    Seville_wind_speed  4.475845e+00
# 14     Barcelona_rain_1h  1.547539e+00
# 15      Seville_pressure  9.698391e+00
# 16       Seville_rain_1h  2.117250e+00
# 17        Bilbao_snow_3h  1.276235e+00
# 18    Barcelona_pressure  1.045837e+00
# 19       Seville_rain_3h  1.090637e+00
# 20        Madrid_rain_1h  2.296527e+00
# 21     Barcelona_rain_3h  1.081474e+00
# 22      Valencia_snow_3h  1.192666e+00
# 23     Madrid_weather_id  2.648622e+02
# 24  Barcelona_weather_id  1.209964e+02
# 25       Bilbao_pressure  2.354233e+04
# 26    Seville_weather_id  2.903626e+02
# 27     Valencia_pressure  4.517666e+04
# 28      Seville_temp_max  2.492749e+05
# 29       Madrid_pressure  7.947904e+03
# 30     Valencia_temp_max  3.576013e+05
# 31         Valencia_temp  1.221595e+06
# 32     Bilbao_weather_id  8.229326e+01
# 33          Seville_temp  1.555250e+06
# 34     Valencia_humidity  3.637794e+01
# 35     Valencia_temp_min  3.196925e+05
# 36    Barcelona_temp_max  1.792018e+05
# 37       Madrid_temp_max  1.082383e+05
# 38        Barcelona_temp  7.284634e+05
# 39       Bilbao_temp_min  4.592497e+05
# 40           Bilbao_temp  1.559554e+06
# 41    Barcelona_temp_min  2.328898e+05
# 42       Bilbao_temp_max  3.705760e+05
# 43      Seville_temp_min  5.679343e+05
# 44           Madrid_temp  2.971866e+05
# 45       Madrid_temp_min  4.465841e+04
# 46                  Year  4.489519e+04
# 47               Quarter  1.219933e+02
# 48                 Month  7.765868e+02
# 49                  Week  9.968337e+01
# 50           Day_of_week  3.318456e+00
# 51           Day_of_year  6.561709e+02
# 52                  Hour  5.121570e+00

# %%
New_X = X.copy()

# %%
New_X = New_X.drop(['Madrid_wind_speed'], axis=1)
calculate_vif(New_X)
# Out:
#                 Features           VIF
# 0      Valencia_wind_deg  6.740373e+00
# 1         Bilbao_rain_1h  2.039581e+00
# 2    Valencia_wind_speed  3.995897e+00
# 3       Seville_humidity  4.820568e+01
# 4        Madrid_humidity  4.163006e+01
# 5      Bilbao_clouds_all  4.526760e+00
# 6      Bilbao_wind_speed  4.000389e+00
# 7     Seville_clouds_all  2.711421e+00
# 8        Bilbao_wind_deg  5.370759e+00
# 9   Barcelona_wind_speed  4.884583e+00
# 10    Barcelona_wind_deg  7.046274e+00
# 11     Madrid_clouds_all  3.351106e+00
# 12    Seville_wind_speed  4.217585e+00
# 13     Barcelona_rain_1h  1.547735e+00
# 14      Seville_pressure  9.529091e+00
# 15       Seville_rain_1h  2.131251e+00
# 16        Bilbao_snow_3h  1.271178e+00
# 17    Barcelona_pressure  1.041294e+00
# 18       Seville_rain_3h  1.093855e+00
# 19        Madrid_rain_1h  2.352866e+00
# 20     Barcelona_rain_3h  1.080108e+00
# 21      Valencia_snow_3h  1.188727e+00
# 22     Madrid_weather_id  2.638121e+02
# 23  Barcelona_weather_id  1.202211e+02
# 24       Bilbao_pressure  2.310918e+04
# 25    Seville_weather_id  2.862089e+02
# 26     Valencia_pressure  4.458391e+04
# 27      Seville_temp_max  2.512738e+05
# 28       Madrid_pressure  7.631890e+03
# 29     Valencia_temp_max  3.434941e+05
# 30         Valencia_temp  1.204595e+06
# 31     Bilbao_weather_id  8.221539e+01
# 32          Seville_temp  1.568384e+06
# 33     Valencia_humidity  3.606015e+01
# 34     Valencia_temp_min  3.185634e+05
# 35    Barcelona_temp_max  1.802241e+05
# 36       Madrid_temp_max  1.066273e+05
# 37        Barcelona_temp  7.251402e+05
# 38       Bilbao_temp_min  4.741766e+05
# 39           Bilbao_temp  1.614885e+06
# 40    Barcelona_temp_min  2.283773e+05
# 41       Bilbao_temp_max  3.835084e+05
# 42      Seville_temp_min  5.741763e+05
# 43           Madrid_temp  2.932494e+05
# 44       Madrid_temp_min  4.524550e+04
# 45                  Year  4.372003e+04
# 46               Quarter  1.211508e+02
# 47                 Month  7.786457e+02
# 48                  Week  1.007335e+02
# 49           Day_of_week  3.321663e+00
# 50           Day_of_year  6.571398e+02
# 51                  Hour  5.060246e+00

# %%
"""df_train_drop = X_train.drop(to_drop_features, axis=1)
df_test_drop = X_test.drop(to_drop_features,axis=1)"""
# Out:
# 'df_train_drop = X_train.drop(to_drop_features, axis=1)\ndf_test_drop = X_test.drop(to_drop_features,axis=1)'

# %%
#copying selected VIF features after applying VIF for Feature Selection
vif_X_features = New_X.copy()

# %% [markdown]
# ### Two feature selection group

# %%
#Features left after using Using Pearson Correlation to drop others
corr_X_features.head(2)
# Out:
#                      Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# time
# 2015-04-01 00:00:00           2.000000                  6             0.3
# 2017-06-26 06:00:00           1.666667                  6             0.0
#
#                      Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# time
# 2015-04-01 00:00:00             1.000000         61.666667             61.0
# 2017-06-26 06:00:00             1.666667         77.666667             92.0
#
#                      Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# time
# 2015-04-01 00:00:00               90.0           1.000000                 0.0
# 2017-06-26 06:00:00               20.0           0.666667                 0.0
#
#                      Bilbao_wind_deg  Barcelona_wind_speed  \
# time
# 2015-04-01 00:00:00       317.333333              1.000000
# 2017-06-26 06:00:00        30.000000              2.333333
#
#                      Barcelona_wind_deg  Madrid_clouds_all  \
# time
# 2015-04-01 00:00:00               163.0                6.0
# 2017-06-26 06:00:00               200.0               40.0
#
#                      Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  \
# time
# 2015-04-01 00:00:00            1.666667                0.0                20
# 2017-06-26 06:00:00            0.666667                0.0                 3
#
#                      Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  \
# time
# 2015-04-01 00:00:00              0.0             0.0         1025.333333
# 2017-06-26 06:00:00              0.0             0.0         1012.333333
#
#                      Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# time
# 2015-04-01 00:00:00              0.0             0.0           0.006667
# 2017-06-26 06:00:00              0.0             0.0           0.000000
#
#                      Valencia_snow_3h  Madrid_weather_id  \
# time
# 2015-04-01 00:00:00               0.0         800.333333
# 2017-06-26 06:00:00               0.0         605.000000
#
#                      Barcelona_weather_id  Bilbao_pressure  \
# time
# 2015-04-01 00:00:00                 800.0      1033.666667
# 2017-06-26 06:00:00                 800.0      1010.000000
#
#                      Seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2015-04-01 00:00:00          800.000000        1018.000000        290.777323
# 2017-06-26 06:00:00          770.333333        1011.333333        293.150000
#
#                      Madrid_pressure  Valencia_temp_max  Valencia_temp  \
# time
# 2015-04-01 00:00:00           1028.0         285.335656     285.335656
# 2017-06-26 06:00:00           1013.0         295.483333     295.483333
#
#                      Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# time
# 2015-04-01 00:00:00              500.0    290.777323               61.0
# 2017-06-26 06:00:00              801.0    292.743333               90.0
#
#                      Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# time
# 2015-04-01 00:00:00         285.335656          285.935667       283.552333
# 2017-06-26 06:00:00         295.483333          296.150000       291.483333
#
#                      Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# time
# 2015-04-01 00:00:00      285.935667          282.969      282.969
# 2017-06-26 06:00:00      295.816667          290.150      291.050
#
#                      Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# time
# 2015-04-01 00:00:00          285.935667          282.969        290.777323
# 2017-06-26 06:00:00          295.483333          292.150        292.483333
#
#                      Madrid_temp  Madrid_temp_min  Year  Quarter  Month  Week  \
# time
# 2015-04-01 00:00:00   283.552333       283.552333  2015        2      4    14
# 2017-06-26 06:00:00   291.073333       290.816667  2017        2      6    26
#
#                      Day_of_week  Day_of_year  Hour
# time
# 2015-04-01 00:00:00            2           91     0
# 2017-06-26 06:00:00            0          177     6

# %%
#copying selected VIF features after applying VIF for Feature Selection
vif_X_features.head(2)
# Out:
#                      Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# time
# 2015-01-01 03:00:00                  5             0.0             0.666667
# 2015-01-01 06:00:00                 10             0.0             1.666667
#
#                      Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# time
# 2015-01-01 03:00:00         74.333333        64.000000                0.0
# 2015-01-01 06:00:00         78.333333        64.666667                0.0
#
#                      Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# time
# 2015-01-01 03:00:00                1.0                 0.0       223.333333
# 2015-01-01 06:00:00                1.0                 0.0       221.000000
#
#                      Barcelona_wind_speed  Barcelona_wind_deg  \
# time
# 2015-01-01 03:00:00              6.333333           42.666667
# 2015-01-01 06:00:00              4.000000          139.000000
#
#                      Madrid_clouds_all  Seville_wind_speed  Barcelona_rain_1h  \
# time
# 2015-01-01 03:00:00                0.0            3.333333                0.0
# 2015-01-01 06:00:00                0.0            3.333333                0.0
#
#                      Seville_pressure  Seville_rain_1h  Bilbao_snow_3h  \
# time
# 2015-01-01 03:00:00                25              0.0             0.0
# 2015-01-01 06:00:00                25              0.0             0.0
#
#                      Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# time
# 2015-01-01 03:00:00         1036.333333              0.0             0.0
# 2015-01-01 06:00:00         1037.333333              0.0             0.0
#
#                      Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# time
# 2015-01-01 03:00:00                0.0               0.0              800.0
# 2015-01-01 06:00:00                0.0               0.0              800.0
#
#                      Barcelona_weather_id  Bilbao_pressure  \
# time
# 2015-01-01 03:00:00                 800.0      1035.000000
# 2015-01-01 06:00:00                 800.0      1035.666667
#
#                      Seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2015-01-01 03:00:00               800.0        1002.666667        274.254667
# 2015-01-01 06:00:00               800.0        1004.333333        274.945000
#
#                      Madrid_pressure  Valencia_temp_max  Valencia_temp  \
# time
# 2015-01-01 03:00:00       971.333333         269.888000     269.888000
# 2015-01-01 06:00:00       972.666667         271.728333     271.728333
#
#                      Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# time
# 2015-01-01 03:00:00              800.0    274.254667          75.666667
# 2015-01-01 06:00:00              800.0    274.945000          71.000000
#
#                      Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# time
# 2015-01-01 03:00:00         269.888000          281.013000       265.938000
# 2015-01-01 06:00:00         271.728333          280.561667       266.386667
#
#                      Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# time
# 2015-01-01 03:00:00      281.013000       269.338615   269.338615
# 2015-01-01 06:00:00      280.561667       270.376000   270.376000
#
#                      Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# time
# 2015-01-01 03:00:00          281.013000       269.338615        274.254667
# 2015-01-01 06:00:00          280.561667       270.376000        274.945000
#
#                      Madrid_temp  Madrid_temp_min  Year  Quarter  Month  Week  \
# time
# 2015-01-01 03:00:00   265.938000       265.938000  2015        1      1     1
# 2015-01-01 06:00:00   266.386667       266.386667  2015        1      1     1
#
#                      Day_of_week  Day_of_year  Hour
# time
# 2015-01-01 03:00:00            3            1     3
# 2015-01-01 06:00:00            3            1     6

# %% [markdown]
# ### Standardization

# %% [markdown]
# #### Box Cox Transformation of (highly) skewed corr_X_features

# %%
numeric_feats_corr = corr_X_features.dtypes[corr_X_features.dtypes != "object"].index

# Check the skew of all numerical features
skewed_feats_corr = corr_X_features[numeric_feats_corr].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
corr_X_features_skewness = pd.DataFrame({'Skew' :skewed_feats_corr})
corr_X_features_skewness.head(3)
# Out:
# Skew in numerical features:
#                          Skew
# Valencia_snow_3h    76.223760
# Barcelona_pressure  52.320848
# Bilbao_snow_3h      26.539494

# %%
corr_X_features_skewness = corr_X_features_skewness[abs(corr_X_features_skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(corr_X_features_skewness.shape[0]))

from scipy.special import boxcox1p
skewed_features_corr = corr_X_features_skewness.index
lam = 0.15
for feat in skewed_features_corr:
    #all_data[feat] += 1
    corr_X_features[feat] = boxcox1p(corr_X_features[feat], lam)
    
#all_data[skewed_features] = np.log1p(all_data[skewed_features])
# Out:
# There are 53 skewed numerical features to Box Cox transform

# %% [markdown]
# #### Box Cox Transformation of (highly) skewed corr_X_features test dataset

# %%
# Check the skew of all numerical features
skewed_feats_corr_test = df_test_eng_corr.apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in df_test_eng_corr features: \n")
corr_X_features_skewness_test = pd.DataFrame({'Skew' :skewed_feats_corr_test})
corr_X_features_skewness_test.head(3)
# Out:
# Skew in df_test_eng_corr features:
#                         Skew
# Seville_rain_3h    54.009262
# Barcelona_rain_3h  39.996770
# Seville_rain_1h     6.265984

# %%
corr_X_features_skewness_test = corr_X_features_skewness_test[abs(corr_X_features_skewness_test) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(corr_X_features_skewness_test.shape[0]))

from scipy.special import boxcox1p
skewed_features_corr_test = corr_X_features_skewness_test.index
lam = 0.15
for feat in skewed_features_corr_test:
    #all_data[feat] += 1
    df_test_eng_corr[feat] = boxcox1p(df_test_eng_corr[feat], lam)
    
#all_data[skewed_features] = np.log1p(all_data[skewed_features])
# Out:
# There are 53 skewed numerical features to Box Cox transform

# %%
df_test_eng_corr.head(2)
# Out:
#                      Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# time
# 2018-01-01 00:00:00           2.055642           2.602594             0.0
# 2018-01-01 03:00:00           1.981178           2.602594             0.0
#
#                      Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# time
# 2018-01-01 00:00:00             2.055642          6.382451         6.004293
# 2018-01-01 03:00:00             2.126668          6.426513         6.172972
#
#                      Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# time
# 2018-01-01 00:00:00           3.858807           1.540963                 0.0
# 2018-01-01 03:00:00           0.000000           1.732956                 0.0
#
#                      Bilbao_wind_deg  Barcelona_wind_speed  \
# time
# 2018-01-01 00:00:00         8.029052              1.820334
# 2018-01-01 03:00:00         7.387780              1.981178
#
#                      Barcelona_wind_deg  Madrid_clouds_all  \
# time
# 2018-01-01 00:00:00            7.832720                0.0
# 2018-01-01 03:00:00            8.752038                0.0
#
#                      Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  \
# time
# 2018-01-01 00:00:00            0.730463                0.0          4.201461
# 2018-01-01 03:00:00            0.530906                0.0          4.201461
#
#                      Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  \
# time
# 2018-01-01 00:00:00              0.0             0.0           12.173825
# 2018-01-01 03:00:00              0.0             0.0           12.182140
#
#                      Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# time
# 2018-01-01 00:00:00              0.0             0.0                0.0
# 2018-01-01 03:00:00              0.0             0.0                0.0
#
#                      Valencia_snow_3h  Madrid_weather_id  \
# time
# 2018-01-01 00:00:00               0.0          11.507463
# 2018-01-01 03:00:00               0.0          11.507463
#
#                      Barcelona_weather_id  Bilbao_pressure  \
# time
# 2018-01-01 00:00:00             11.507463        12.196872
# 2018-01-01 03:00:00             11.508597        12.199627
#
#                      Seville_weather_id  Valencia_pressure  Seville_temp_max  \
# time
# 2018-01-01 00:00:00           11.507463          12.170123          8.901800
# 2018-01-01 03:00:00           11.507463          12.170123          8.885391
#
#                      Madrid_pressure  Valencia_temp_max  Valencia_temp  \
# time
# 2018-01-01 00:00:00        12.208793           8.926232       8.926232
# 2018-01-01 03:00:00        12.209708           8.899072       8.899072
#
#                      Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# time
# 2018-01-01 00:00:00          11.510864      8.895167           5.223387
# 2018-01-01 03:00:00          11.226587      8.878718           5.483077
#
#                      Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# time
# 2018-01-01 00:00:00           8.926232            8.928933         8.871642
# 2018-01-01 03:00:00           8.899072            8.904526         8.868884
#
#                      Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# time
# 2018-01-01 00:00:00        8.925205         8.832772     8.868028
# 2018-01-01 03:00:00        8.899400         8.846718     8.873240
#
#                      Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# time
# 2018-01-01 00:00:00            8.920821         8.907248          8.890872
# 2018-01-01 03:00:00            8.893608         8.899072          8.874397
#
#                      Madrid_temp  Madrid_temp_min       Year   Quarter  \
# time
# 2018-01-01 00:00:00     8.863774         8.857823  14.210867  0.730463
# 2018-01-01 03:00:00     8.858183         8.849498  14.210867  0.730463
#
#                         Month      Week  Day_of_week  Day_of_year      Hour
# time
# 2018-01-01 00:00:00  0.730463  0.730463          0.0     0.730463  0.000000
# 2018-01-01 03:00:00  0.730463  0.730463          0.0     0.730463  1.540963

# %% [markdown]
# #### Implementing Scaling on Selected VIF Predictor Features

# %%
# import scaler method from sklearn
from sklearn.preprocessing import StandardScaler

#Creating a scaler object
scaler = StandardScaler()

# %%
#create scaled version of the VIF selected predictor features
vif_scaled_X_features = scaler.fit_transform(vif_X_features)

# %%
#convert the scaled predictor values into a dataframe
vif_standardise_x_features = pd.DataFrame(
    vif_scaled_X_features, columns=vif_X_features.columns)

vif_standardise_x_features.head(3)
# Out:
#    Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  \
# 0          -0.096053       -0.362123            -0.796169          0.516117
# 1           1.641580       -0.362123            -0.381412          0.692953
# 2           1.294054       -0.362123            -0.657917          0.383491
#
#    Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# 0         0.270621          -1.335491          -0.501451           -0.565065
# 1         0.298017          -1.335491          -0.501451           -0.565065
# 2         0.284319          -1.335491          -0.501451           -0.565065
#
#    Bilbao_wind_deg  Barcelona_wind_speed  Barcelona_wind_deg  \
# 0         0.630823              1.932284           -1.660205
# 1         0.607959              0.630270           -0.578686
# 2         0.542632             -0.485743            1.520733
#
#    Madrid_clouds_all  Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  \
# 0          -0.694188            0.542975          -0.203099          1.588087
# 1          -0.694188            0.542975          -0.203099          1.588087
# 2          -0.694188            0.144442          -0.203099          1.588087
#
#    Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  \
# 0        -0.224278       -0.057269           -0.024277        -0.066278
# 1        -0.224278       -0.057269           -0.024206        -0.066278
# 2        -0.224278       -0.057269           -0.024158        -0.066278
#
#    Madrid_rain_1h  Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0       -0.247776          -0.110037         -0.017312           0.342424
# 1       -0.247776          -0.110037         -0.017312           0.342424
# 2       -0.247776          -0.110037         -0.017312           0.342424
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0              0.385993         1.718219            0.352274
# 1              0.385993         1.784583            0.352274
# 2              0.385993         1.817765            0.352274
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0          -1.242351         -2.616796        -1.756232          -2.835227
# 1          -1.050427         -2.539014        -1.696165          -2.591966
# 2          -0.935272         -2.105564        -1.636097          -1.761812
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0      -2.890888           0.649842     -2.490266           0.540928
# 1      -2.633926           0.649842     -2.403108           0.298645
# 2      -1.757012           0.649842     -1.917409           0.021750
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0          -2.892663           -1.394813        -2.420380       -1.354598
# 1          -2.626219           -1.456868        -2.374370       -1.423738
# 2          -1.716949           -1.316350        -1.726058       -1.267176
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0        -2.338357    -2.505658           -1.218309        -2.621665
# 1        -2.183645    -2.353511           -1.292271        -2.475661
# 2        -1.489980    -1.671342           -1.124792        -1.821036
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min      Year   Quarter  \
# 0         -2.125118    -2.405393        -2.309892 -1.226179 -1.351096
# 1         -2.040702    -2.357388        -2.261154 -1.226179 -1.351096
# 2         -1.570279    -1.680968        -1.574407 -1.226179 -1.351096
#
#       Month      Week  Day_of_week  Day_of_year      Hour
# 0 -1.602429 -1.709703     -0.00274    -1.728991 -1.090901
# 1 -1.602429 -1.709703     -0.00274    -1.728991 -0.654451
# 2 -1.602429 -1.709703     -0.00274    -1.728991 -0.218001

# %% [markdown]
# #### Implementing Scaling on Pearson Correlation Selected Predictor Features

# %%
#create scaled version of the VIF selected predictor features
corr_scaled_X_features = scaler.fit_transform(corr_X_features)

# %%
#convert the scaled predictor values into a dataframe
corr_standardise_x_features = pd.DataFrame(
    corr_scaled_X_features, columns=corr_X_features.columns)

corr_standardise_x_features.head(3)
# Out:
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 0          -0.052254           0.422601        0.733653            -0.762409
# 1          -0.288677           0.422601       -0.439670            -0.268986
# 2          -1.191596          -1.816687       -0.439670            -1.422671
#
#    Seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 0          0.124051         0.312276           0.970133          -0.425607
# 1          0.682407         1.195421          -0.137573          -0.753670
# 2          0.671805        -0.232307          -0.388278          -0.141146
#
#    Seville_clouds_all  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0           -0.703945         1.010238             -1.187726
# 1           -0.703945        -1.082854             -0.130707
# 2            0.729651         0.194020              0.075636
#
#    Barcelona_wind_deg  Madrid_clouds_all  Seville_wind_speed  \
# 0           -0.017163           0.041874           -0.326144
# 1            0.290232           1.125693           -1.268007
# 2            1.101435          -0.861756           -0.910506
#
#    Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  Bilbao_snow_3h  \
# 0          -0.262180          0.839834        -0.249915       -0.073522
# 1          -0.262180         -1.657148        -0.249915       -0.073522
# 2           0.702491         -0.882890        -0.249915       -0.073522
#
#    Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# 0           -0.022388        -0.065869        -0.26846           1.572788
# 1           -0.060527        -0.065869        -0.26846          -0.108439
# 2           -0.049728        -0.065869        -0.26846          -0.108439
#
#    Valencia_snow_3h  Madrid_weather_id  Barcelona_weather_id  Bilbao_pressure  \
# 0         -0.016011           0.330079              0.371029         1.563716
# 1         -0.016011          -2.018155              0.371029        -0.774166
# 2         -0.016011           0.326509             -0.594648        -0.375787
#
#    Seville_weather_id  Valencia_pressure  Seville_temp_max  Madrid_pressure  \
# 0            0.331120           0.519753         -0.761823         0.782086
# 1           -0.019707          -0.233235         -0.489593         0.125909
# 2            0.338876           0.181428          1.697741         0.228520
#
#    Valencia_temp_max  Valencia_temp  Bilbao_weather_id  Seville_temp  \
# 0          -0.791519      -0.731012          -1.955710     -0.404204
# 1           0.557521       0.688041           0.633924     -0.153084
# 2           0.818761       0.764685           0.039594      0.742898
#
#    Valencia_humidity  Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# 0          -0.077677          -0.652586           -0.718214        -0.611385
# 1           1.124310           0.815074            0.695055         0.211775
# 2           0.619632           0.561230            0.386414         0.173797
#
#    Barcelona_temp  Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# 0       -0.597719        -0.301582    -0.506783           -0.405909
# 1        0.915507         0.768841     0.680640            1.147149
# 2        0.404793        -0.123969     0.324593            0.231154
#
#    Bilbao_temp_max  Seville_temp_min  Madrid_temp  Madrid_temp_min      Year  \
# 0        -0.707131         -0.097632    -0.516127        -0.388605 -1.221129
# 1         0.589780          0.112094     0.295607         0.403512  1.222702
# 2         0.470705          0.112094    -0.284658        -1.553368 -1.221129
#
#     Quarter     Month      Week  Day_of_week  Day_of_year      Hour
# 0 -0.326173 -0.535122 -0.574055    -0.237260    -0.535936 -2.133956
# 1 -0.326173  0.071777  0.214633    -1.861686     0.230401 -0.277562
# 2  0.529502  0.749455  0.706193     0.614204     0.680839  0.125462

# %% [markdown]
# #### Implementing Scaling on the test dataset

# %%
#create scaled version of the VIF selected predictor features
df_test_eng_corr_scaled = scaler.fit_transform(df_test_eng_corr)

# %%
#convert the scaled predictor values into a dataframe
corr_standardise_x_features_test = pd.DataFrame(
    df_test_eng_corr_scaled , columns=df_test_eng_corr.columns)

corr_standardise_x_features_test.head(3)
# Out:
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 0           1.457673           0.717708       -0.468242             1.103519
# 1           1.322969           0.717708       -0.468242             1.228849
# 2           0.126062           0.449428       -0.468242             1.103519
#
#    Seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 
seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 0          0.124051         0.312276           0.970133          -0.425607
# 1          0.682407         1.195421          -0.137573          -0.753670
# 2          0.671805        -0.232307          -0.388278          -0.141146
#
#    Seville_clouds_all  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0           -0.703945         1.010238             -1.187726
# 1           -0.703945        -1.082854             -0.130707
# 2            0.729651         0.194020              0.075636
#
#    Barcelona_wind_deg  Madrid_clouds_all  Seville_wind_speed  \
# 0           -0.017163           0.041874           -0.326144
# 1            0.290232           1.125693           -1.268007
# 2            1.101435          -0.861756           -0.910506
#
#    Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  Bilbao_snow_3h  \
# 0          -0.262180          0.839834        -0.249915       -0.073522
# 1          -0.262180         -1.657148        -0.249915       -0.073522
# 2           0.702491         -0.882890        -0.249915       -0.073522
#
#    Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# 0           -0.022388        -0.065869        -0.26846           1.572788
# 1           -0.060527        -0.065869        -0.26846          -0.108439
# 2           -0.049728        -0.065869        -0.26846          -0.108439
#
#    Valencia_snow_3h  Madrid_weather_id  Barcelona_weather_id  Bilbao_pressure  \
# 0         -0.016011           0.330079              0.371029         1.563716
# 1         -0.016011          -2.018155              0.371029        -0.774166
# 2         -0.016011           0.326509             -0.594648        -0.375787
#
#    Seville_weather_id  Valencia_pressure  Seville_temp_max  Madrid_pressure  \
# 0            0.331120           0.519753         -0.761823         0.782086
# 1           -0.019707          -0.233235         -0.489593         0.125909
# 2            0.338876           0.181428          1.697741         0.228520
#
#    Valencia_temp_max  Valencia_temp  Bilbao_weather_id  Seville_temp  \
# 0          -0.791519      -0.731012          -1.955710     -0.404204
# 1           0.557521       0.688041           0.633924     -0.153084
# 2           0.818761       0.764685           0.039594      0.742898
#
#    Valencia_humidity  Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# 0          -0.077677          -0.652586           -0.718214        -0.611385
# 1           1.124310           0.815074            0.695055         0.211775
# 2           0.619632           0.561230            0.386414         0.173797
#
#    Barcelona_temp  Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# 0       -0.597719        -0.301582    -0.506783           -0.405909
# 1        0.915507         0.768841     0.680640            1.147149
# 2        0.404793        -0.123969     0.324593            0.231154
#
#    Bilbao_temp_max  Seville_temp_min  Madrid_temp  Madrid_temp_min      Year  \
# 0        -0.707131         -0.097632    -0.516127        -0.388605 -1.221129
# 1         0.589780          0.112094     0.295607         0.403512  1.222702
# 2         0.470705          0.112094    -0.284658        -1.553368 -1.221129
#
#     Quarter     Month      Week  Day_of_week  Day_of_year      Hour
# 0 -0.326173 -0.535122 -0.574055    -0.237260    -0.535936 -2.133956
# 1 -0.326173  0.071777  0.214633    -1.861686     0.230401 -0.277562
# 2  0.529502  0.749455  0.706193     0.614204     0.680839  0.125462

# %% [markdown]
# #### Implementing Scaling on the X_corr

# %%
#create scaled version of the VIF selected predictor features
X_corr_scaled = scaler.fit_transform(X_corr)

# %%
#convert the scaled predictor values into a dataframe
corr_standardise_X = pd.DataFrame(
    X_corr_scaled , columns=X_corr.columns)

corr_standardise_X.head(3)
# Out:
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 0          -0.950708          -0.096053       -0.362123            -0.796169
# 1          -1.130863           1.641580       -0.362123            -0.381412
# 2          -0.770554           1.294054       -0.362123            -0.657917
#
#    Seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 0          0.516117         0.270621          -1.335491          -0.501451
# 1          0.692953         0.298017          -1.335491          -0.501451
# 2          0.383491         0.284319          -1.335491          -0.501451
#
#    Seville_clouds_all  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0           -0.565065         0.630823              1.932284
# 1           -0.565065         0.607959              0.630270
# 2           -0.565065         0.542632             -0.485743
#
#    Barcelona_wind_deg  Madrid_clouds_all  Seville_wind_speed  \
# 0           -1.660205          -0.694188            0.542975
# 1           -0.578686          -0.694188            0.542975
# 2            1.520733          -0.694188            0.144442
#
#    Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  Bilbao_snow_3h  \
# 0          -0.203099          1.588087        -0.224278       -0.057269
# 1          -0.203099          1.588087        -0.224278       -0.057269
# 2          -0.203099          1.588087        -0.224278       -0.057269
#
#    Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  \
# 0           -0.024277        -0.066278       -0.247776          -0.110037
# 1           -0.024206        -0.066278       -0.247776          -0.110037
# 2           -0.024158        -0.066278       -0.247776          -0.110037
#
#    Valencia_snow_3h  Madrid_weather_id  Barcelona_weather_id  Bilbao_pressure  \
# 0         -0.017312           0.342424              0.385993         1.718219
# 1         -0.017312           0.342424              0.385993         1.784583
# 2         -0.017312           0.342424              0.385993         1.817765
#
#    Seville_weather_id  Valencia_pressure  Seville_temp_max  Madrid_pressure  \
# 0            0.352274          -1.242351         -2.616796        -1.756232
# 1            0.352274          -1.050427         -2.539014        -1.696165
# 2            0.352274          -0.935272         -2.105564        -1.636097
#
#    Valencia_temp_max  Valencia_temp  Bilbao_weather_id  Seville_temp  \
# 0          -2.835227      -2.890888           0.649842     -2.490266
# 1          -2.591966      -2.633926           0.649842     -2.403108
# 2          -1.761812      -1.757012           0.649842     -1.917409
#
#    Valencia_humidity  Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  \
# 0           0.540928          -2.892663           -1.394813        -2.420380
# 1           0.298645          -2.626219           -1.456868        -2.374370
# 2           0.021750          -1.716949           -1.316350        -1.726058
#
#    Barcelona_temp  Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# 0       -1.354598        -2.338357    -2.505658           -1.218309
# 1       -1.423738        -2.183645    -2.353511           -1.292271
# 2       -1.267176        -1.489980    -1.671342           -1.124792
#
#    Bilbao_temp_max  Seville_temp_min  Madrid_temp  Madrid_temp_min      Year  \
# 0        -2.621665         -2.125118    -2.405393        -2.309892 -1.226179
# 1        -2.475661         -2.040702    -2.357388        -2.261154 -1.226179
# 2        -1.821036         -1.570279    -1.680968        -1.574407 -1.226179
#
#     Quarter     Month      Week  Day_of_week  Day_of_year      Hour
# 0 -1.351096 -1.602429 -1.709703     -0.00274    -1.728991 -1.090901
# 1 -1.351096 -1.602429 -1.709703     -0.00274    -1.728991 -0.654451
# 2 -1.351096 -1.602429 -1.709703     -0.00274    -1.728991 -0.218001

# %% [markdown]
# ### Data processing for test data

# %% [markdown]
# The same step for done to process the train data set were repeated for the test data set

# %% [markdown]
# <a id="six"></a>
# ## 6. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Modelling ⚡ |
# | :--------------------------- |
# | In this section, you are required to create one or more regression models that are able to accurately predict the thee hour load shortfall. |
#
# ---

# %% [markdown]
# We use the **cross_val_score** function of Sklearn. However this function has not a shuffle attribut, we add then one line of code,  in order to shuffle the dataset  prior to cross-validation

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(corr_standardise_X.values)
    rmse= np.sqrt(-cross_val_score(model, corr_standardise_x_features.values, y_train.values, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %% [markdown]
# The data is split for Hold-out_validation

# %%
# split data

#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80, test_size = 0.2, random_state=15)

#print(X_train.shape)
#print(X_test.shape)
#print(y_train.shape)
#print(y_test.shape)

# %% [markdown]
# ### Base Models

# %% [markdown]
# #### 1. Gradient Boosting Regression :

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %% [markdown]
# #### 2. XGBoost :

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %% [markdown]
# #### 3. LightGBM :

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %% [markdown]
# #### 4. RandomForest

# %%
#Add more models

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model performance ⚡ |
# | :--------------------------- |
# | In this section you are required to compare the relative performance of the various trained ML models on a holdout dataset and comment on what model is the best and why. |
#
# ---

# %% [markdown]
# The perfomance of the the base models were evaluated using the cross-validation rmsle error

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 3048.5941 (25.1342)

# %%
#Previous score Gradient Boosting score: 4164.1072 (121.5695)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [21:58:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [21:58:38] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [21:58:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [21:58:54] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [21:59:02] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# Xgboost score: 3088.3350 (34.0285)

# %%
#Previous score Xgboost score: 4170.3357 (123.7141)

# %%
score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# LGBM score: 3557.1736 (16.7412)

# %%
#Previous score LGBM score: 4034.4399 (197.5265)

# %% [markdown]
# <a id="eight"></a>
# ## 8. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---

# %% [markdown]
# #### 8.1. Gradient Boosting Regression

# %% [markdown]
# #### 8.2. XGBoost

# %% [markdown]
# #### 8.3. LightGBM

# %% [markdown]
# #### 8.4. Random Forest

# %% [markdown]
# #### Chosen Model :

# %%
# discuss chosen methods logic

# %% [markdown]
# <a id="nine"></a>
# ## 9. Conclusion
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |

# %% [markdown]
# ### Making submision

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
model_xgb.fit(corr_standardise_X, y)
xgb_train_pred = model_xgb.predict(corr_standardise_X)
xgb_pred = (model_xgb.predict(corr_standardise_x_features_test.values))
print(rmsle(y, xgb_train_pred))
# Out:
# [22:04:53] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0ac76685cf763591d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# 1959.2164742535615

# %%
model_lgb.fit(corr_standardise_X, y)
lgb_train_pred = model_lgb.predict(corr_standardise_X)
lgb_pred = (model_lgb.predict(corr_standardise_x_features_test.values))
print(rmsle(y, lgb_train_pred))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# 3235.111591020818

# %% [markdown]
# #### Ensemble prediction:

# %%
ensemble = xgb_pred*0.80 + lgb_pred*0.20

# %% [markdown]
# #### Submission

# %%
daf = pd.DataFrame(ensemble, columns=['load_shortfall_3h'])
daf.head()
# Out:
#    load_shortfall_3h
# 0        7176.527828
# 1        2002.288001
# 2        6886.810927
# 3        8939.658605
# 4        7429.258823

# %%
output = pd.DataFrame({"time":df_test['time']})
submission = output.join(daf)
submission.to_csv("submission.csv", index=False)

# %% [markdown]
# <a id="ten"></a>
# ## 10. Referencess
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |

# %% [markdown]
# [1] Environmental Protection Agency. (n.d.). EPA. Retrieved November 4, 2022, from https://www.epa.gov/statelocalenergy/local-renewable-energy-benefits-and-resources

# %% [markdown]
# [2] Centric Consulting (2021) Machine learning: A quick introduction and five core steps, Centric Consulting. Available at: https://centricconsulting.com/blog/machine-learning-a-quick-introduction-and-five-core-steps/ (Accessed: November 4, 2022).

# %% [markdown]
# [3] http://onlinestatbook.com/2/transformations/box-cox.html

# %% [markdown]
# [4] https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.special.boxcox1p.html
